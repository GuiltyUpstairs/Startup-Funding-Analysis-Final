# %% [markdown]
# # 1-Question:
# Your Friend has developed the Product and he wants to establish the product startup and he is searching for a perfect location where getting the investment has a high chance. But due to its financial restriction, he can choose only between three locations - Bangalore, Mumbai, and NCR. As a friend, you want to help your friend deciding the location. NCR include Gurgaon, Noida and New Delhi. Find the location where the most number of funding is done. That means, find the location where startups has received funding maximum number of times. Plot the bar graph between location and number of funding. Take city name "Delhi" as "New Delhi". Check the case-sensitiveness of cities also. That means, at some place instead of "Bangalore", "bangalore" is given. Take city name as "Bangalore". For few startups multiple locations are given, one Indian and one Foreign. Consider the startup if any one of the city lies in given locations.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# read startup_funding.csv file using pandas
data = pd.read_csv("C:/Users/HP/Desktop/Case Study-Startup/startup_funding2.csv")
df = data.copy()
# drop null values from CityLocation column 
df.drop(df.index[df.CityLocation.isnull()], inplace = True)

# correct spelling usning replace function
df['CityLocation'].replace("bangalore","Bangalore",inplace = True)
df['CityLocation'].replace("Delhi","New Delhi",inplace = True)

# store Bangalore,Mumbai,Gurgaon,Noida and New Delhi and 
# startups has received funding maximum number of times using Dict 
dic = {}
for i in df['CityLocation']:
    if 'Bangalore' in i:
        dic['Bangalore'] = dic.get('Bangalore', 0) + 1
    elif 'Mumbai' in i:
        dic['Mumbai'] = dic.get('Mumbai', 0) + 1
    elif 'Gurgaon' in i:
        dic['Gurgaon'] = dic.get('Gurgaon', 0) + 1
    elif 'Noida' in i:
        dic['Noida'] = dic.get('Noida', 0) + 1
    elif 'New Delhi' in i:
        dic['New Delhi'] = dic.get('New Delhi', 0) + 1

# stored cities in X and stored received_funding maximum number of times for each city in Y
x = list(dic.keys())
y = list(dic.values())
# create np array by X and Y
np_x = np.array(x)
np_y = np.array(y)

# sort np_x array with the help of np_y using argsort fun
np_x = np_x[np.argsort(np_y)]
# sort np_y array
np_y = np.sort(np_y)

# extact top 5 cities where startups has received funding maximum number of times
np_x = np_x[len(np_x)-1:-1-5:-1]
np_y = np_y[len(np_y)-1:-1-5:-1]

# Plot the pie graph between location and number of funding
plt.pie(np_y, labels= np_x, autopct = '%.2f%%')
plt.show()

# Plot the bar graph between location and number of funding
plt.bar(np_x, np_y)
plt.xticks(rotation = 40)
plt.yticks(np_y)
plt.show()

for i in range(len(np_x)):
    print(np_x[i], np_y[i])
# Out:
# Bangalore 637
# Mumbai 449
# New Delhi 389
# Gurgaon 241
# Noida 79

# %% [markdown]
# # 2- Question
# Even after trying for so many times, your friend’s startup could not find the investment. So you decided to take this matter in your hand and try to find the list of investors who probably can invest in your friend’s startup. Your list will increase the chance of your friend startup getting some initial investment by contacting these investors. Find the top 5 investors who have invested maximum number of times (consider repeat investments in one company also). In a startup, multiple investors might have invested. So consider each investor for that startup. Ignore undisclosed investors.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# read startup_funding.csv file using pandas
data = pd.read_csv("C:/Users/HP/Desktop/Case Study-Startup/startup_funding2.csv")
df = data.copy()

# create np array by InvestorsName column and dtype is string
np_investor = np.array(df.InvestorsName, dtype = 'str') 

# create a list all the investors who have invested In a startup
investors = []
for row in np_investor:
    # Ignore undisclosed investors
    if 'Undisclosed' not in row or 'undisclosed' in row:
        val = row.split(',')
        for name in val:
            investors.append(name.strip())

# stored investors in Dict.keys and 
# stored maximum number of times invested In a startup for each investor in Dict.values
Dict = {}
for key in investors:
    if key in Dict:
        Dict[key] += 1
    else:
        Dict[key] = 1
# stored investors in X-list who have invested In a startup by Dict.keys
x = list(Dict.keys())
# stored values of maximum number of times invested In a startup for each investor by Dict.values
y = list(Dict.values())

np_x = np.array(x)
np_y = np.array(y)

# sort np_x array with the help of np_y using argsort fun
np_x = np_x[np.argsort(np_y)]
# sort np_y array
np_y = np.sort(np_y)

# extact top 5 investors who have invested maximum number of times in a startup
np_x = np_x[len(np_x)-1: len(np_x) -1-5 : -1]
np_y = np_y[len(np_y)-1: len(np_y) -1-5 : -1]

# plot pie graph using np_y and np_x array
plt.pie(np_y, labels= np_x, autopct = '%.2f%%')
plt.show()

# plot line graph
plt.plot(np_x, np_y, 'o--')
plt.grid()
plt.xticks(rotation = 40)
plt.show()

for i in range(len(np_x)):
    print(np_x[i], np_y[i])
# Out:
# Sequoia Capital 64
# Accel Partners 52
# Kalaari Capital 44
# SAIF Partners 41
# Indian Angel Network 40

# %% [markdown]
# # 3- Question
# After re-analysing the dataset you found out that some investors have invested in the same startup at different number of funding rounds. So before finalising the previous list, you want to improvise it by finding the top 5 investors who have invested in different number of startups. This list will be more helpful than your previous list in finding the investment for your friend startup. Find the top 5 investors who have invested maximum number of times in different companies. That means, if one investor has invested multiple times in one startup, count one for that company. There are many errors in startup names. Ignore correcting all, just handle the important ones - Ola, Flipkart, Oyo and Paytm.

# %%
df.head()
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3  Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                     Narottam Thudi, Shireesh Palle    Seed Funding
#
#   AmountInUSD Remarks
# 0   1,300,000     NaN
# 1         NaN     NaN
# 2         NaN     NaN
# 3     500,000     NaN
# 4     850,000     NaN

# %%
# drop null values from InvestorsName column 
df.drop(df.index[df.InvestorsName.isnull()], inplace = True)

# drop 'Undisclosed Investors' values from InvestorsName column 
df.drop(df.index[df.InvestorsName == 'Undisclosed Investors'], inplace = True)

# drop null values from StartupName column 
df.drop(df.index[df.StartupName.isnull()], inplace = True)

# correct spelling mistakes- Ola, Flipkart, Oyo and Paytm using replace fun
df["StartupName"].replace("Flipkart.com","Flipkart",inplace = True) 
df["StartupName"].replace("Ola Cabs","Ola",inplace = True)
df["StartupName"].replace("Olacabs","Ola",inplace = True)
df["StartupName"].replace("Oyorooms","Oyo",inplace = True)
df["StartupName"].replace("OyoRooms","Oyo",inplace = True)
df["StartupName"].replace("OYO Rooms","Oyo",inplace = True)
df["StartupName"].replace("Oyo Rooms","Oyo",inplace = True)
df["StartupName"].replace("Paytm Marketplace","Paytm",inplace = True)

# %%
# create np array by InvestorsName column and dtype is string       
np_investor = np.array(df.InvestorsName, dtype = 'str')

# create np array by StartupName column and dtype is string
np_startup = np.array(df.StartupName, dtype = 'str')

# stored investors who have invested maximum number of times in different companies in Dict.keys and 
# stored values of invested maximum number of times in different companies in Dict.values
Dict = {}
for i in range(len(np_investor)):
    investor = np_investor[i].strip()
    if "," in investor:
        val = investor.strip().split(',')
        for name in val:
            if name.strip() in Dict:
                if np_startup[i] not in Dict[name.strip()]:
                    Dict[name.strip()].add(np_startup[i].strip())
            else:
                s = set()
                Dict[name.strip()] = s
                Dict[name.strip()].add(np_startup[i].strip())
    else:
        name = investor.strip()
        if name in Dict:
            if np_strtup[i] not in Dict[name]:
                Dict[name].add(np_startup[i].strip())
        else:
            s = set()
            Dict[name] = s
            Dict[name].add(np_startup[i].strip())

# %%
Dict
# Out:
# {'Kae Capital': {'Azuro',
#   'Daily Rounds',
#   'Frsh',
#   'Frsh.co.in',
#   'Fynd',
#   'HandyHome',
#   'HealthKart',
#   'Hypernova Interactive',
#   'LearnTron',
#   'ListUp',
#   'Loantap',
#   'Nudgespot',
#   'Parentune',
#   'Shopsense',
#   'The Porter',
#   'TouchKin',
#   'Truebil',
#   'TrulyMadly.com',
#   'Trupay',
#   'numberz.in'},
#  'Triton Investment Advisors': {'Ethinos'},
#  'Kashyap Deorah': {'Leverage Edu', 'Meesho', 'Springboard'},
#  'Anand Sankeshwar': {'Leverage Edu', 'ShopsUp'},
#  'Deepak Jain': {'Leverage Edu'},
#  'Sadashiva NT': {'Leverage Edu'},
#  'Arjun Mehta': {'Leverage Edu'},
#  'Satish Kaul': {'Leverage Edu'},
#  'Anindya Ghose': {'Leverage Edu'},
#  'Kunal Shah': {'Bharat Bazaar',
#   'Cookifi',
#   'Daily Ninja',
#   'Flyrobe',
#   'Innov8',
#   'Lets Reap',
#   'LifCare',
#   'ListUp',
#   'Pianta',
#   'Pocket Aces',
#   'ShaadiSaga',
#   'Spinny',
#   'TableHero',
#   'Twigly',
#   'UnaAcademy',
#   'Zepo',
#   'enCashea'},
#  'LetsVenture': {'Aisle',
#   'Betaout',
#   'BookEventz',
#   'CollateBox',
#   'FalconBrick',
#   'Footprints Education',
#   'Gridle',
#   'JustLikeNew',
#   'Ketto',
#   'LetsMD',
#   'Massblurb',
#   'MyGreens',
#   'Netree',
#   'Nightstay',
#   'OnlineRTI',
#   'SavvyMob',
#   'Zepo'},
#  'Anupam Mittal': {'Blinge',
#   'CareonGO',
#   'Daily Ninja',
#   'HashLearn',
#   'InnerChef',
#   'InstaLively.com',
#   'LetsMD',
#   'Near.in',
#   'ShaadiSaga',
#   'Splitkart',
#   'The Porter',
#   'Truce',
#   'Truebil',
#   'Vebbler',
#   'WitWorks',
#   'Yumlane',
#   'Zepo',
#   'infeedo'},
#  'Hetal Sonpal': {'Zepo'},
#  'Narottam Thudi': {'Click2Clinic'},
#  'Shireesh Palle': {'Click2Clinic'},
#  'Reliance Corporate Advisory Services Ltd': {'Billion Loans'},
#  'Infuse Ventures': {'Ecolibriumenergy',
#   'EzySolare',
#   'Fourth Partner Energy',
#   'GIBSS',
#   'Glowship',
#   'Karma Recycling',
#   'Proviera',
#   'Silvan Innovation Labs'},
#  'JLL': {'Ecolibriumenergy', 'ZipGrid'},
#  'Asset Management (Asia) Ltd': {'Droom'},
#  'Digital Garage Inc': {'Droom'},
#  'Kalaari Capital': {'Active.ai',
#   'Advenio',
#   'Affordplan',
#   'Airpay',
#   'AppDaily',
#   'AppsDaily',
#   'Appsdaily',
#   'Bestdealfinance',
#   'BlueStone',
#   'Casa2inns',
#   'Cashkaro.com',
#   'CreditVidya',
#   'Crowdfire (formerly Justunfollow)',
#   'Curefit',
#   'Cyclops',
#   'Doormint',
#   'Eatfresh',
#   'ElastiRun',
#   'ElasticRun',
#   'Grabhouse.com',
#   'Guarented',
#   'HolaChef',
#   'Holachef',
#   'IndustryBuying',
#   'Jumbotail',
#   'POPxo.com',
#   'ParaBlu',
#   'RKSV',
#   'Robosoft',
#   'Rubique',
#   'ScoopWhoop',
#   'Shopalyst',
#   'Simplilearn',
#   'Stalk Buy Love',
#   'Triphobo',
#   'Truebil',
#   'Truweight',
#   'UniLog',
#   'Urban Ladder',
#   'Velmenni',
#   'Volta Motors'},
#  'Nexus India Capital Advisors': {'Jumbotail'},
#  'International Finance Corporation': {'Moglix', 'Power2SME'},
#  'Rocketship': {'Fynd', 'Moglix'},
#  'Accel Partners': {'4tigo',
#   'Agrostar',
#   'Bizongo',
#   'BlackBuck',
#   'Blackbuck',
#   'Bluestone',
#   'BookMyShow',
#   'Casa2inns',
#   'ChargeBee',
#   'Collectabillia',
#   'Consure Medical',
#   'Crown-it',
#   'Crownit',
#   'CureJoy',
#   'Curefit',
#   'DailyRounds',
#   'FabHotels',
#   'FreshDesk',
#   'Good Methods Global',
#   'Indifi',
#   'Juspay',
#   'LetsVenture',
#   'ManageMySpa',
#   'Mech Mocha',
#   'Mihup',
#   'Milofy',
#   'Moglix',
#   'Mubble',
#   'MySmartPrice',
#   'Ninjacart',
#   'Opinio',
#   'Portea Medical',
#   'Power2SME',
#   'QikPod',
#   'RentMojo',
#   'Scripbox',
#   'Sepalika',
#   'Sigtuple',
#   'Swiggy',
#   'Systemantics',
#   'Teabox',
#   'UrbanClap',
#   'Vedantu',
#   'Wizrocket',
#   'Zarget',
#   'Zinka',
#   'ZopNow'},
#  'Jungle Ventures': {'Commeasure',
#   'LivSpace',
#   'Mobikon',
#   'Moglix',
#   'Momoe',
#   'Paysense',
#   'Pokkt',
#   'RedDoorz',
#   'SnapBizz',
#   'Tookitaki',
#   'Vayana'},
#  'Shailesh Rao': {'Moglix'},
#  'Venture Highway': {'Betterplace', 'Moglix', 'ShareChat'},
#  'BCCL': {'Timesaverz'},
#  'Blume Ventures': {'BHIVE Workspace',
#   'BhiveWorkspace',
#   'Buddy',
#   'Chillr',
#   'DataWeave',
#   'FastFox',
#   'FlipClass',
#   'Glamrs',
#   'GreytHR',
#   'HealthifyMe',
#   'Locus',
#   'Mech Mocha',
#   'Minjar',
#   'MockBank',
#   'MonkeyBox',
#   'NowFloats',
#   'Prepathon',
#   'RailYatri',
#   'ReGlobe',
#   'Roadrunnr',
#   'Runnr',
#   'Servify',
#   'SnapBizz',
#   'Spinny',
#   'Squadrun',
#   'Tookitaki',
#   'UnaAcademy',
#   'Unacademy',
#   'Unocoin',
#   'Verayu',
#   'Zenatix',
#   'belong',
#   'iService',
#   'intouchapp',
#   'm.paani',
#   'mPaani'},
#  'Contrarian Capital India Partners': {'Minjar'},
#  'Emergent Ventures India': {'Minjar'},
#  'Pallav Nadhani': {'HealthifyMe', 'Minjar', 'MyChild App', 'The Ken'},
#  'Ashish Gupta': {'Biryani By Kilo',
#   'Fastudent',
#   'Minjar',
#   'Sattviko',
#   'Tpot'},
#  'Sharad Sharma': {'Amigobulls', 'Minjar', 'MyPoolin', 'Wishberry'},
#  'Sirion Labs': {'Minjar'},
#  'India Quotient': {'Belita',
#   'CREO',
#   'Care24',
#   'Clip App',
#   'CreditMate',
#   'FabAlley',
#   'Frsh.co.in',
#   'GoComet',
#   'HolaChef',
#   'Holachef',
#   'IIM Jobs',
#   'LendingKart',
#   'Loantap',
#   'Purple Squirrel',
#   'ShareChat',
#   'Teewe',
#   'WealthTrust',
#   'rBus'},
#  'Shunwei Capital': {'Clip App', 'Mech Mocha', 'Truebil'},
#  'Sreeram Iyer': {'Upwardly.in'},
#  'Suvo Sarkar': {'Upwardly.in'},
#  'Anita Gupta': {'Upwardly.in'},
#  'Likemind Ventures': {'Upwardly.in'},
#  'Mitsui & Co.': {'Autorox.co', 'Naaptol'},
#  'Dunamis Ventures Pte Ltd': {'Fabogo'},
#  'Venture Catalysts': {'Beardo',
#   'Coutloot',
#   'Flickstree',
#   'Fynd',
#   'GoMechanic',
#   'PeeSafe.in',
#   'SIFTR Labs'},
#  'Sourav Ganguly': {'Flickstree'},
#  'Ankit Aditya': {'Flickstree'},
#  'Moksh Sports Ventures': {'Flickstree'},
#  'Fireside Ventures': {'Bounty App',
#   'Delight Foods',
#   'Design Cafe',
#   'Vahdam Teas',
#   'WitWorks'},
#  'Apurva Salarpuria': {'Design Cafe'},
#  'Sidharth Pansari': {'Design Cafe', 'Dropkaffe'},
#  'Sprout Capital': {'Design Cafe'},
#  'SBI-FMO Fund': {'Innoviti'},
#  'Bessemer Venture Partners': {'BigBasket',
#   'CanvasFlip',
#   'Innoviti',
#   'LivSpace',
#   'Perfios',
#   'PharmEasy',
#   'StayGlad',
#   'Swiggy',
#   'Travel Triangle',
#   'UrbanClap',
#   'Vidooly',
#   'Wydr'},
#  'Catamaran Ventures': {'Innoviti', 'Lookup'},
#  'Corvus Ventures': {'Tinmen', 'VDeliver'},
#  'MAPE Advisory Group': {'Tinmen', 'VDeliver'},
#  '500 Startups': {'Bottr.me',
#   'Capabiliti',
#   'EduKart',
#   'Ftcash',
#   'HeadOut',
#   'Kartrocket',
#   'LafaLafa',
#   'Niramai',
#   'OnlineTyari',
#   'POPxo.com',
#   'Quickli',
#   'Reddoorz',
#   'Sheroes',
#   'Springboard',
#   'StalkBuyLove',
#   'SwitchMe',
#   'TransTutors / AskIITians',
#   'Tripoto',
#   'Wishup'},
#  'Purvi Capital': {'AdPushUp', 'Bottr.me', 'Jobspire'},
#  'Rajan Anandan': {'AppVirality',
#   'Bottr.me',
#   'Dazo',
#   'Fulfil.IO',
#   'HashLearn',
#   'Indifi',
#   'Innov8',
#   'Innovaccer',
#   'InstaLively',
#   'Little Black Book Delhi',
#   'Lucideus',
#   'Maya',
#   'Monsoon Fintech',
#   'MyPoolin',
#   'Omnify',
#   'Smartcooky',
#   'Smytten',
#   'SwitchMe',
#   'Unacademy',
#   'Vista Rooms',
#   'Weddingz.in',
#   'Wishberry',
#   'Zenatix'},
#  'Abhishek Gupta': {'Bottr.me', 'Swajal'},
#  'Indian Angel Network': {'6Degree',
#   'Adytude',
#   'Arcatron',
#   'Consure Medical',
#   'DesignBids',
#   'DrivoJoy',
#   'FabAlley',
#   'FarMart',
#   'Flatpebble',
#   'Fourseven',
#   'Infinity Assurance',
#   'Jiyo Natural',
#   'Lawrato',
#   'Little Black Book',
#   'Native Special',
#   'NeuroSynaptic',
#   'Oneway.cab',
#   'Orahi',
#   'Paytunes',
#   'PeeBuddy',
#   'Pikkol',
#   'PipeCandy',
#   'Process 9',
#   'PropheSee',
#   'RepUp',
#   'Roast',
#   'SP Robotics',
#   'Shoekonnect',
#   'Shopatplaces',
#   'SmartVizX',
#   'Spinny',
#   'Staqu',
#   'Styledotme',
#   'The BlueBook',
#   'ThinkerBell',
#   'Transcell',
#   'Unbxd',
#   'WOW! MOMO',
#   'WedmeGood.com',
#   'Wiwigo'},
#  'Brigade Innovations LLP': {'QwikSpec'},
#  'TV Mohandas Pai': {'Bharat Bazaar',
#   'CimplyFive',
#   'Gingercrush',
#   'JustDoc',
#   'Kaaryah',
#   'Licious',
#   'Magic Crate',
#   'OnlineTyari',
#   'QwikSpec',
#   'SavvyMob',
#   'Smartcooky',
#   'TaxSutra',
#   'Velvetcase',
#   'Wigzo'},
#  'Suhail Rahman': {'QwikSpec'},
#  'Bobby Reddy': {'QwikSpec'},
#  'M George Oommen': {'QwikSpec'},
#  'Blacksoil Capital Pvt. Ltd': {'Chumbak'},
#  'Sequoia Capital': {'1mg',
#   '1mg (Healthkartplus)',
#   'Akosha',
#   'B9 Beverages',
#   'Byju’s',
#   'CREO',
#   'Capillary Tech',
#   'Capital Float',
#   'Chillr',
#   'Citrus Payment',
#   'Cleartax',
#   'Craftstvilla',
#   'CueMath',
#   'Faasos',
#   'Fintellix',
#   'Flyrobe',
#   'FreeCharge',
#   'Goodservice',
#   'Grabhouse.com',
#   'Grofers',
#   'Groupon India',
#   'HelpChat',
#   'HomeLane',
#   'Increff',
#   'Ixigo',
#   'Kredx',
#   'La Renon',
#   'MedGenome',
#   'MobiKwik',
#   'NearBuy (previously\xa0 groupon India)',
#   'OneAssist',
#   'Oyo',
#   'PepperTap',
#   'Practo',
#   'PressPlay',
#   'PressPlay TV',
#   'Roadrunnr',
#   'Shuttl',
#   'SirionLabs',
#   'Teewe',
#   'The Porter',
#   'TinyOwl',
#   'Urban Ladder',
#   'Voonik',
#   'Wizrocket',
#   'Zoomcar',
#   'practo'},
#  'Grey Orange': {'Increff'},
#  'Rajesh Ramaiah': {'Increff'},
#  'Anshuman Das': {'Increff'},
#  'Rishi Das': {'Increff'},
#  'IDG Ventures India Advisors': {'Vayana'},
#  'One97 Communication Ltd': {'MObiquest'},
#  'Uber Technologies Inc': {'Ambee'},
#  'Amaya Capital LLP': {'Ambee'},
#  'Xelpmoc': {'121Policy', 'Ideal Insurance'},
#  'ain Capital Ventures': {'Rentomojo'},
#  'Renaud Laplanche': {'Rentomojo'},
#  'Francesco Cara': {'AirCTO'},
#  'ABI-Showatech (India) Ltd': {'Playablo'},
#  'M&S Partners': {'Healthians',
#   'InnerChef',
#   'Joolz',
#   'Ninjacart',
#   'SilverPush',
#   'SparesHub',
#   'Trupay'},
#  '': {'4tigo',
#   'Aahaa',
#   'AppDaily',
#   'Baxi',
#   'Boxmyspace',
#   'Cashe',
#   'Crofarm',
#   'DailyNinja',
#   'EasyPolicy',
#   'FiTraQ',
#   'Fitso',
#   'Galleri5',
#   'Haqdarshak',
#   'Indus OS',
#   'LetsMD',
#   'Loanmeet',
#   'Mad Street Den',
#   'Magicpin',
#   'MotoMojo',
#   'MyGubbi',
#   'MyTaxiIndia',
#   'Nayi Disha',
#   'Noticeboard',
#   'PharmEasy',
#   'SP Robotics',
#   'Saral Designs',
#   'Smartcooky',
#   'Splitkart',
#   'Sport Flashes',
#   'Startup Buddy',
#   'TopRankers',
#   'TripFactory',
#   'Trupay',
#   'WeAreHolidays',
#   'Yana',
#   'infeedo',
#   'kredX',
#   'mPaani'},
#  'Subramani Somasundaram': {'Brick2Wall'},
#  'Sundeep Sahni': {'Brick2Wall'},
#  'Mayank Mittal & Others': {'Brick2Wall'},
#  'Harmeet Bajaj': {'FableStreet'},
#  'Pameela P': {'FableStreet'},
#  'Fusiontech Ventures & Others': {'FableStreet'},
#  'Sunil Kalra': {'HashLearn',
#   'Innov8',
#   'Monsoon Fintech',
#   'MyPoolin',
#   'ZipLoan'},
#  'Aditya Singh': {'Monsoon Fintech'},
#  'Rishi Srivastava': {'Monsoon Fintech'},
#  'NB Ventures': {'Healthifyme', 'MonkeyBox', 'Qriyo'},
#  'Nspira': {'MonkeyBox'},
#  'Stellaris Venture Partners': {'Noticeboard', 'Whatfix', 'Wydr'},
#  'Tencent Holdings': {'Byju’s', 'Flipkart', 'Hike'},
#  'Yuvraj Singh': {'Creator’s Gurukul', 'Intelligent Interfaces'},
#  'Goldman Sachs': {'Antuit',
#   'Better Mortgage',
#   'Fab Hotels',
#   'Foodpanda',
#   'Mamagoto',
#   'Pepperfry'},
#  'Anand Mahindra': {'DishCo', 'LocalCircles', 'SheThePeople', 'ThinkerBell'},
#  'HBM Healthcare Investments': {'1mg'},
#  'Maverick Capital Ventures': {'1mg'},
#  'Sequoia India': {'1mg',
#   'Awfis',
#   'Byju’s',
#   'CraftsVilla',
#   'CueMath',
#   'Druva',
#   'Knowlarity',
#   'Mad Street Den',
#   'MoneyTap',
#   'Peppertap',
#   'Vymo',
#   'Zarget',
#   'Zefo',
#   'Zilingo'},
#  'Omidyar Network and Kae Capital': {'1mg'},
#  'Amen Dhyllon': {'Jhakaas'},
#  'Info Edge (India) Ltd': {'BigStylist',
#   'Canvera',
#   'Diro Labs',
#   'HappilyUnmarried',
#   'Rare Media'},
#  'RoundGlass Partners': {'BabyChakra',
#   'Curofy',
#   'Doctor Insta',
#   'DoctorInsta',
#   'Gympik',
#   'Gympik.com',
#   'Life in Control',
#   'Obino',
#   'Xcode',
#   'Zoojoo.be'},
#  'Grace Grace Techno Ventures LLP': {'Tripeur'},
#  'Rajul Garg & Other undisclosed investors': {'Tripeur'},
#  'TVS Motor Company': {'RentOnGo'},
#  'Emerging India': {'Goomo'},
#  'blockchain ecosystem Global Advisors': {'MaxMyWealth'},
#  'Horseferry': {'MaxMyWealth'},
#  'Sandeep Tandon': {'Bharat Bazaar',
#   'Flyrobe',
#   'Lets Reap',
#   'LifCare',
#   'ListUp',
#   'Pianta',
#   'Pocket Aces',
#   'Remitr',
#   'ShaadiSaga',
#   'Spinny',
#   'TableHero',
#   'The Porter',
#   'UnaAcademy',
#   'enCashea'},
#  'Arun Patodia': {'Healthbuds'},
#  'Bharat Kedia': {'Healthbuds'},
#  'IvyCap Ventures': {'BlueStone',
#   'Bluestone',
#   'Clovia',
#   'FTCash',
#   'Ftcash',
#   'Purplle.com',
#   'RML Agtech',
#   'Sokrati',
#   'Taskbob'},
#  'Harsh Mahajan': {'wayForward'},
#  'Farhan Naqvi': {'wayForward'},
#  'Sreepathy Viswanathan': {'wayForward'},
#  'Sundaram Finance Holdings': {'GyanDhan'},
#  'SBI (Stand Up India Scheme)': {'Hungry Foal'},
#  'WaterBridge Ventures': {'DataWeave', 'LetsMD', 'ZipLoan'},
#  'SQue Capital': {'GrowFitter', 'SidQam'},
#  'Bodhtree Consulting Limited': {'Stratfit'},
#  'Norwest Venture Partners': {'ABI Health',
#   'Attune Technologies',
#   'Capillary Tech',
#   'ElastiRun',
#   'ElasticRun',
#   'Manthan',
#   'Multiplier Solutions',
#   'Pepperfry',
#   'Qubole',
#   'RevX',
#   'Swiggy',
#   'Zenoti'},
#  'Mohan Alexander': {'Stockal'},
#  'R. Natarajan': {'Stockal'},
#  'Vikrant Varshney': {'Stockal'},
#  'Amit Sinha': {'Stockal'},
#  'Pawan Borle': {'Guiddoo', 'Guidoo'},
#  'Nirmal Singh': {'Guidoo'},
#  'Manish Prasad': {'Guidoo'},
#  'Vineet Varma': {'Guidoo'},
#  'Nick Haulkoury': {'Guidoo'},
#  'Abhai S. Rao': {'Guidoo'},
#  'Dr Ramesh Ayyala': {'eSahai.in'},
#  'Satya Muthyala': {'eSahai.in'},
#  'Cao Yibin': {'Loanmeet'},
#  'Huang Wei': {'Loanmeet'},
#  'Madhusudan E': {'Loanmeet'},
#  'Yes Bank': {'LendingKart'},
#  'Unicorn India Ventures': {'Boxx.ai',
#   'NeuroEquilibrium',
#   'PharmaRack',
#   'Roder',
#   'Sequretek'},
#  'Venky Krishnakumar': {'Boxx.ai'},
#  'Suresh Shankar': {'Boxx.ai'},
#  'Vivek Bhargava': {'Awesummly', 'Boxx.ai', 'Corseco', 'infeedo'},
#  'Alfa Capital': {'PeeSafe.in'},
#  'Green Shots Capital': {'PeeSafe.in'},
#  'Real Time Ventures': {'PeeSafe.in'},
#  'Artha India Ventures': {'Vista Rooms'},
#  'Singularity Holdings': {'Vista Rooms'},
#  'Girish Mathrubootham': {'BookEventz',
#   'CrownIt',
#   'GoBumpr',
#   'Hubilo',
#   'Inkmonk',
#   'Innov8',
#   'MadRat Games',
#   'The Ken',
#   'Tracxn',
#   'Vista Rooms',
#   'Whatfix',
#   'Zarget',
#   'iService'},
#  'Transamerica': {'CoverFox'},
#  'Nexus Venture Partners': {'Arkin Net',
#   'CraftsVilla',
#   'Delhivery',
#   'GoPigeon',
#   'Goodbox',
#   'Goodera',
#   'HyperTrack',
#   'Indix',
#   'Infoworks',
#   'Lybrate',
#   'Postman',
#   'PratiLipi',
#   'RevX',
#   'Roadrunnr',
#   'Runnr',
#   'Shopclues',
#   'Stayzilla',
#   'TinyOwl',
#   'Turtlemint',
#   'Unacademy',
#   'ZoloStays'},
#  'Founders Fund': {'HyperTrack'},
#  'Omidyar Network': {'1mg',
#   '1mg (Healthkartplus)',
#   'DailyHunt',
#   'Goodera',
#   'HealthKart',
#   'Indifi',
#   'Indus OS',
#   'NeoGrowth',
#   'NewsLaundry',
#   'NowFloats',
#   'Overcart.com',
#   'Scripbox',
#   'Vistaar Finance',
#   'ZestMoney',
#   'Zimmber'},
#  'Fairfax Holdings': {'Digit'},
#  'Tekne Capital Management LLC': {'Ola'},
#  'RB Investments': {'BlueStone',
#   'Capricoast',
#   'Faasos',
#   'FabHotels',
#   'Impact Guru',
#   'InstantPay',
#   'Travel Triangle',
#   'Vanitycask',
#   'Voonik'},
#  'undisclosed investors': {'Aequm',
#   'Affimity',
#   'BankerBay',
#   'Dekkho',
#   'Genie',
#   'Hoopy',
#   'MrNeeds',
#   'QikShip',
#   'Sumeru',
#   'UrbanPiper',
#   'ZippServe'},
#  'NEA': {'HyperVerge', 'IDfy', 'MoneyTap'},
#  'Prime Venture Partners': {'Affordplan',
#   'HackerEarth',
#   'LoveCycles',
#   'MoneyTap',
#   'NiYO Solutions',
#   'kredX'},
#  'Mekin Maheshwari': {'Explore Life traveling',
#   'Goodbox',
#   'Hansel.io',
#   'Makkajai'},
#  'Mohammed Khan': {'Fincash'},
#  'Sameer Narayan & Others': {'Fincash'},
#  'Alphard Maritime Group': {'PortDesk'},
#  'Cross Border Angels & Experts': {'EdgeFx', 'eShiksha'},
#  'Rajasthan Angel Innovators Network': {'EdgeFx', 'Kalaage'},
#  'The Chennai Angels': {'Brigge',
#   'Cloudcherry Analytics',
#   'EdgeFx',
#   'Fourth Partner Energy',
#   'Get My Parking',
#   'Netree',
#   'Silvan',
#   'Spares Hub',
#   'Syona Cosmetics',
#   'The Postbox',
#   'Vegetall'},
#  'YouWeCan Ventures': {'Black White Orange Brands',
#   'Carl’s Jr',
#   'Cartisan',
#   'EazyDiner',
#   'EduKart',
#   'Healthians',
#   'Moovo',
#   'SportyBeans',
#   'Startup Buddy',
#   'Vyomo'},
#  'BLIP Initiatives': {'HealthIntel'},
#  'Eight Roads Ventures': {'Celes Care',
#   'ChaiPoint',
#   'Icertis',
#   'Medwell Ventures',
#   'Shadowfax',
#   'Shadowfox',
#   'Unbxd'},
#  'Lightspeed India Partners': {'DarwinBox',
#   'FastFox',
#   'Magicpin',
#   'ShareChat'},
#  'Endiya Partners': {'Celes Care',
#   'DarwinBox',
#   'Hansel.io',
#   'Kissht',
#   'Sigtuple'},
#  '3one4 Capital Advisors LLP': {'DarwinBox'},
#  'Startupxseed Ventures LLP': {'DarwinBox'},
#  '91maker.com': {'ForeverShop'},
#  'Paytm': {'Insider.in',
#   'Jugnoo',
#   'LogiNext',
#   'QorQI',
#   'TapChief',
#   'The/Nudge Foundation',
#   'Zovi.com / Little App'},
#  'IIFL Seed Ventures': {'Fynd'},
#  'FJ Labs': {'Fynd'},
#  'Singularity Ventures': {'Fynd', 'StalkBuyLove', 'Weddingz.in'},
#  'GrowX': {'Fynd'},
#  'Tracxn Labs': {'Buddy',
#   'Cookifi',
#   'Daily Ninja',
#   'DarwinBox',
#   'Elanic',
#   'Fynd',
#   'Klozee',
#   'Parcelled',
#   'Qyk App',
#   'StayGlad',
#   'Twigly',
#   'ZenRadius',
#   'enCashea'},
#  'Axis Capital': {'Fynd', 'Wydr'},
#  'Manipal Education and Medical Group (MEMG)': {'Grow Fit'},
#  'SAR Group': {'Grow Fit'},
#  'The Grover Trust': {'Grow Fit'},
#  'iBhubs': {'Fabulyst'},
#  'UC-RNT Fund': {'mSwipe'},
#  'Matrix Partners': {'DailyHunt',
#   'Frankly',
#   'Housejoy',
#   'LimeRoad.com',
#   'Loadshare',
#   'Mswipe',
#   'Myra',
#   'OfBusiness',
#   'Practo',
#   'Razorpay',
#   'StayZilla',
#   'Stayzilla',
#   'TinyOwl',
#   'Zarget',
#   'mSwipe',
#   'practo'},
#  'alcon Edge Capital': {'mSwipe'},
#  'DSG Consumer Partners': {'EazyDiner',
#   'India Lends',
#   'IndiaLends',
#   'Mswipe',
#   'Superhero Brands',
#   'Tazzo Bikes',
#   'Veeba Foods',
#   'mSwipe'},
#  'General Catalyst': {'Julia Computing'},
#  'Founder Collective': {'Julia Computing'},
#  'Ventureast': {'Celes Care', 'Kissht', 'Portea Medical'},
#  'Bharat Vijay': {'Explore Life traveling'},
#  'Krish Seshadri': {'Explore Life traveling'},
#  'Amar Arsikere': {'Explore Life traveling'},
#  'IFMR': {'Loantap'},
#  'and MAS Financial Services Ltd': {'Loantap'},
#  'Undisclosed investors': {'American Vision',
#   'Appie',
#   'Applicate',
#   'Big Fish Ventures',
#   'Butterfly Interactive',
#   'Crownit',
#   'EasyKhaana',
#   'GetFocus',
#   'GetMyPeon',
#   'HashTaag',
#   'Heads Up For Tails',
#   'HealthEnablr',
#   'Locanix',
#   'Lumiere',
#   'MyDentistChoice',
#   'MyIndianStay',
#   'OUWT',
#   'PinClick',
#   'Pramati',
#   'SchoolWear',
#   'Schoolkart',
#   'Talkoot',
#   'Voxweb',
#   'Zebroads',
#   'Zwayam',
#   'mFicient'},
#  'Mohit Srivastav': {'HUG Innovations'},
#  'Kishore Ganji': {'HUG Innovations'},
#  'Venkat Vallabhaneni': {'HUG Innovations'},
#  'Rajeev Menon': {'HUG Innovations'},
#  'Naspers': {'Flipkart'},
#  'Seedfund': {'Kulzy', 'MyDentist', 'V Resorts', 'Voonik'},
#  'RB International': {'V Resorts'},
#  'Snow Leopard Ventures': {'Stashfin'},
#  'Alto Partners': {'Stashfin'},
#  'Gujarat Venture Finance Ltd': {'Formcept'},
#  'Anthill Scale Ventures': {'Spares Hub'},
#  'Esvee Technologies Inc': {'Spares Hub'},
#  'Inc95 Consulting': {'Spares Hub'},
#  'Aparup Sengupta': {'FiTraQ'},
#  'Devendra Reddy': {'FiTraQ'},
#  'Udayan Goyal': {'Rubique'},
#  'SAP.iO': {'Niki.ai'},
#  'Unilazer Ventures': {'EasyPolicy',
#   'Easypolicy',
#   'Niki.ai',
#   'TimeSaverz',
#   'Yumist'},
#  'Abhinav Bindra': {'Fitpass'},
#  'Gaurav Marya': {'Fitpass'},
#  'Zeta': {'ZingHR'},
#  'Vy Capital': {'Magicpin', 'UrbanClap', 'Zomato'},
#  'SAIF Partners': {'Aye Finance',
#   'BookMyShow',
#   'Bumper',
#   'Capital Float',
#   'Care24',
#   'Chefs Basket',
#   'Cleartax',
#   'FirstCry.com',
#   'Gozoomo',
#   'IndustryBuying',
#   'Niffler',
#   'NoBroker',
#   'PepperTap',
#   'PlaySimple',
#   'Playment',
#   'Pulse',
#   'ShareChat',
#   'SpoonJoy',
#   'Swiggy',
#   'Toppr',
#   'Tracxn',
#   'Travel Triangle',
#   'Treebo',
#   'Urban Ladder',
#   'UrbanClap',
#   'Voodoo',
#   'Xpressbees',
#   'YourDost',
#   'Zovi.com / Little App'},
#  'Accel Partner': {'Moglix', 'UrbanClap'},
#  'Clairvest Group': {'Ace2three'},
#  'Hyderabad Angels': {'Betaout',
#   'Explara',
#   'HealthSutra',
#   'Innovapptive',
#   'RealBox',
#   'SparesHub',
#   'Twigly',
#   'ePathsala',
#   'evibe.in'},
#  'Nandan Nilekani': {'4tigo',
#   'Juggernaut',
#   'Mubble',
#   'Power2SME',
#   'RailYatri',
#   'ShopX',
#   'Systemantics',
#   'Team Indus',
#   'The Print',
#   'Tracxn'},
#  'Dutch government fund': {'SMECorner'},
#  'Falcon Edge Capital': {'Mswipe', 'NewsHunt', 'Ola', 'Quikr'},
#  'Capital Advisers': {'Ola'},
#  'Asuka Holdings': {'Healthians', 'WorkIndia'},
#  'Beenext': {'DailyRounds',
#   'Droom',
#   'HackerEarth',
#   'Healthians',
#   'NoBroker',
#   'WorkIndia',
#   'Zilingo'},
#  'Beenos': {'BuyHatke',
#   'Droom',
#   'Droom.in',
#   'HackerEarth',
#   'Healthians',
#   'NoBroker',
#   'Zilingo'},
#  'Nimit Panigrahi': {'HealthMir', 'SatvaKart'},
#  'Hinduja family': {'Uactive'},
#  '50K Ventures': {'Commut', 'KhanaGadi', 'i-lend'},
#  'Rainmatter': {'Balance App', 'Digio', 'Neotrade Analytics', 'Tradelab'},
#  'Rainbow Digital Services Pvt. Ltd': {'YepMe'},
#  'ILearnFinance Academy Pvt. Ltd.': {'YepMe'},
#  'Indian Angels Network': {'Nightstay', 'ShoeKonnect'},
#  'Deepak Nathani': {'Demyto', 'Devourin', 'Ethosh'},
#  'Ajay Relan': {'LexComply', 'MyGreens', 'Nayi Disha'},
#  'Vertex Ventures': {'Ace Turtle',
#   'CloudCherry',
#   'FirstCry.com',
#   'Flutura',
#   'Housejoy',
#   'Xpressbees'},
#  'C31 Ventures': {'Ace Turtle'},
#  'RNT Capital': {'CureFit'},
#  'Gokul Rajaram': {'CureFit', 'Whatfix'},
#  'Aditya Agarwal': {'CureFit', 'Hike Messenger'},
#  'Ruchi Sanghvi & others': {'CureFit'},
#  'Satoshi Studios': {'Curie Labs'},
#  'Anand Chandrasekaran': {'Buttercups',
#   'CREO',
#   'CrownIt',
#   'GoFynd',
#   'Innov8',
#   'InstaLively.com',
#   'Makkajai',
#   'MoEngage',
#   'NoBroker',
#   'RentOnGo',
#   'Tone Tag',
#   'Uncanny Vision',
#   'Wooplr'},
#  'Luxasia Group': {'Anchanto'},
#  'GVFL': {'Schedulers Logistics', 'Sequretek', 'Vidooly'},
#  'Vellayan Subbiah': {'Industrybuying', 'Lucideus'},
#  'Jonathan Boutelle': {'Lucideus'},
#  'Rahul Chawla': {'Lucideus'},
#  'Salil Donde': {'Lucideus'},
#  'Amit Ranjan': {'Inayo',
#   'InstaLively',
#   'Lucideus',
#   'MyPoolin',
#   'SquadRun',
#   'Wishberry',
#   'betaout'},
#  'Govind Rajan & Others': {'Lucideus'},
#  'Times Internet': {'Bluegape.com',
#   'Culture Machine',
#   'Delhivery',
#   'Jiffstore',
#   'MintM',
#   'Myra',
#   'Ridlr',
#   'TaskBucks',
#   'Vidooly',
#   'ZopNow'},
#  'InnoVen Capital': {'Shopclues', 'Toppr.com', 'Voonik'},
#  '1Crowd': {'Fourth Ambit', 'Idea Bubbles', 'ZipGrid'},
#  'Varsha Rao': {'Chymera VR'},
#  'Surojit Chatterjee': {'Chymera VR'},
#  'Nirav Choksi & Others': {'Chymera VR'},
#  'DG Ventures India': {'Early Salary'},
#  'Dewan Housing Finance Corp': {'Early Salary'},
#  'Chirag Nikunj Sheth & Others': {'Book My Diamond'},
#  'Aakrit Vaish': {'ION Energy'},
#  'Swapan Rajdev': {'ION Energy'},
#  'Sushill Jiwarajka': {'ION Energy'},
#  'Impanix Capital': {'Legal Raasta'},
#  'GEMs': {'Log 9 Materials'},
#  'Infibeam': {'CCAvenue', 'Remit Guru'},
#  'CCavenue': {'Remit Guru'},
#  'IdeaSpring Capital': {'Zapty'},
#  'Kstart Capital': {'Vernacular.ai'},
#  'SAP': {'Niki.ai'},
#  'Innovations East': {'Telr'},
#  'Ayesha Takia Azmi': {'The Good Life'},
#  'Abu Farhan Azmi': {'The Good Life'},
#  'Dr. Ritesh Malik': {'MyChild App', 'PumpKart'},
#  'SoftBank Group': {'Hike', 'Ola', 'Oyo', 'Paytm'},
#  'Dheeraj Pandey': {'EzCred'},
#  'Rajesh Yohannan': {'EzCred', 'Kochi Post'},
#  'Akash Garg': {'EzCred'},
#  'Ankur Capital': {'HealthSutra'},
#  'Gokaldas Exports Ltd': {'YepMe'},
#  'Fosun International': {'Delhivery'},
#  'Eagle10 Ventures': {'TravelSpice'},
#  'Lightspeed Venture Partners': {'CraftsVilla',
#   'FreshMenu',
#   'GetVee',
#   'LimeRoad.com',
#   'LocalOye',
#   'Magicpin',
#   'Oyo',
#   'Qubole',
#   'Red Carpet',
#   'Townrush'},
#  'Ratan Tata': {'Ampere',
#   'Bollant Industries',
#   'CarDekho.com',
#   'Cashkaro',
#   'Crayon Data',
#   'DogSpot',
#   'FirstCry',
#   'GOQii',
#   'HolaChef',
#   'IdeaChakki',
#   'Infinite Analytics',
#   'Invictus Oncology',
#   'KAARYAH',
#   'Kyazoonga',
#   'LensKart',
#   'Lenskart',
#   'Lybrate',
#   'MadRat Games',
#   'Moglix',
#   'Nestaway',
#   'Niki.ai',
#   'Ola',
#   'Paytm',
#   'Sabse',
#   'Snapbizz',
#   'Teabox.com',
#   'The Print',
#   'Tracxn',
#   'UrbanClap',
#   'YourStory'},
#  'Uday Kotak': {'The Print', 'eShakti'},
#  'Vijay Shekhar Sharma': {'Deal Street Asia',
#   'EduKart',
#   'Goqii',
#   'InnerChef',
#   'Innov8',
#   'NoBroker',
#   'Remitr',
#   'Tapchief',
#   'The Print',
#   'UnaAcademy',
#   'betaout'},
#  'Kiran Mazumdar-Shaw': {'The Print', 'UE LifeSciences'},
#  'Rajiv C Mody': {'The Print'},
#  'Trifecta Capital': {'BigBasket',
#   'Box8',
#   'IndustryBuying',
#   'Knowlarity',
#   'PharmEasy',
#   'Securens',
#   'StalkBuyLove',
#   'UrbanClap',
#   'UrbanLadder'},
#  'Blue Orchard': {'Aye Finance'},
#  'Lahiri Music’s family office': {'WhatsLoan'},
#  'PV Sahad': {'Nivesh'},
#  'Sandeep Shroff': {'Nivesh'},
#  'Rahul Gupta': {'Nivesh'},
#  'Carpediem Capital': {'Collateral Medical', 'Gadgetwood'},
#  'Soma Capital': {'Supr Daily'},
#  'Great Oaks Ventures': {'Supr Daily'},
#  '122 West Ventures': {'Supr Daily'},
#  'Nasper': {'Swiggy'},
#  'Accel India': {'Coverfox', 'Swiggy', 'Zenoti'},
#  'Harmony Partners': {'Swiggy'},
#  'Rohto Pharmaceutical': {'SastaSundar'},
#  'Waterbridge Ventures': {'Magicpin'},
#  'Mathew Cyriac': {'Cashe', 'LatestOne'},
#  'Florintree Advisors': {'Cashe'},
#  'Bertelsmann India': {'Eruditus', 'Pepperfry', 'Saavn'},
#  'Matrix Partners India': {'Finomena',
#   'NewsHunt',
#   'OfBusiness',
#   'Purple Squirrel',
#   'Ridlr',
#   'TestBook',
#   'Treebo'},
#  'Quadria Capital Advisors': {'Healthcare at Home'},
#  'Rohitash Gupta': {'Tyre Express'},
#  'Unicorn India Ventures & Others': {'SmartCoin'},
#  'Aspada Investments': {'WayCool'},
#  'Helion Venture Partners': {'Axtria',
#   'Crown-it',
#   'Crownit',
#   'Doormint',
#   'GoZefo',
#   'MoEngage',
#   'MySmartPrice',
#   'RevX',
#   'TrulyMadly.com',
#   'Whatfix',
#   'Wooplr.com',
#   'YepMe',
#   'ZapStitch'},
#  'Powerhouse Ventures': {'DailyRounds', 'Joolz', 'Whatfix'},
#  'Aneesh Reddy': {'Bite Club',
#   'Cookifi',
#   'Elanic',
#   'Innovaccer',
#   'Whatfix',
#   'YourDOST'},
#  'Vispi Daver': {'Whatfix'},
#  'Keyur Joshi': {'Trukky'},
#  'Pavan Bakeri': {'Trukky'},
#  'Koen Bouwers': {'Konsult App'},
#  'Lomesh Agarwal': {'Konsult App'},
#  'Jeroen Mensen': {'Konsult App'},
#  'Pablo van den Bosch & Others': {'Konsult App'},
#  'Deepak Kulkarni': {'Credit Sudhaar'},
#  'Sandeep Pangal': {'Credit Sudhaar'},
#  'Zephyr Peacock India': {'Fingerlix'},
#  'FreakOut Group': {'DataWeave'},
#  'Herb Madan': {'DataWeave'},
#  'Mahindra Partners': {'Medwell Ventures'},
#  'F-Prime Capital Partners': {'Celes Care', 'Medwell Ventures'},
#  'Ishwar Singh': {'Twenty Two Motors'},
#  'Farhaan Shabbir': {'Twenty Two Motors'},
#  'Orios Venture Partners': {'Boxmyspace',
#   'IntelligenceNODE',
#   'PharmEasy',
#   'Pickingo',
#   'PrettySecrets',
#   'Taskbob',
#   'Yumist',
#   'ZapStitch',
#   'Zo Rooms',
#   'ePoise'},
#  'Labruyere Eberlé': {'WonderChef'},
#  'CyberAgent Ventures': {'FastFox'},
#  'GrowX Ventures': {'FastFox', 'TableHero', 'ZipLoan', 'i2e1'},
#  'IMJ Investment Partners': {'FastFox'},
#  'L.D Sharma': {'Omnify'},
#  'Saurabh Arora': {'Omnify'},
#  'Mahindra and Mahindra Financial Services': {'Capital Float'},
#  'Nandan Nilekani’s NRJN Trust': {'Ninjacart'},
#  'Mistletoe': {'InnerChef', 'Ninjacart'},
#  'Qualcomm Ventures': {'AppDaily',
#   'AppsDaily',
#   'Appsdaily',
#   'Ninjacart',
#   'Portea Medical',
#   'Reverie',
#   'Ridlr',
#   'ZopNow'},
#  'Philippe Bouchet': {'MergerWare'},
#  'Sushil Kumar': {'Sports Flashes'},
#  'Sandeep Singh': {'Sports Flashes'},
#  'Ivycap Ventures Advisors': {'Clovia'},
#  'Singularity Ventures and Ravi Dhariwal': {'Clovia'},
#  'Mayfield': {'Emiza', 'Knowlarity', 'Lendingkart'},
#  'Nishant Rao': {'Emiza'},
#  'Dileep Nath': {'Emiza'},
#  'DHI Group Inc': {'HackerEarth'},
#  'Digital Garage': {'Droom', 'HackerEarth', 'NoBroker', 'Zilingo'},
#  'BizReach': {'HackerEarth'},
#  'Contrarian Capital': {'Squadrun'},
#  '91springboard': {'Squadrun'},
#  'Emergent Ventures': {'PipeCandy', 'Squadrun'},
#  'Abstract Ventures': {'Squadrun'},
#  'Anthill Ventures': {'Squadrun'},
#  'Axilor Ventures': {'EasyFix',
#   'Events High',
#   'Infisecure',
#   'Murgency',
#   'NeuroSynaptic',
#   'Niramai',
#   'Petoo',
#   'PipeCandy',
#   'Pocket Aces',
#   'SecururAX',
#   'Squadrun'},
#  'R Ramaraj': {'Tinmen', 'VillFarm'},
#  'Z Nation Lab': {'ScoutMyTrip'},
#  'Redcliffe Capital': {'SafetyKart', 'Simpli5d'},
#  'Urrshila Kerkar': {'WeAreHolidays'},
#  'SIMI Pacific Pte': {'Ola'},
#  'mall Industries Development Bank of India (SIDBI)': {'Myly'},
#  'Tolaram Inc': {'CrediHealth'},
#  'Mountain Pine Capital': {'CrediHealth'},
#  'Benori Ventures LLP': {'Navia Life Care'},
#  'Jacqueline Fernandez': {'Raw Pressery'},
#  'Nibhrant Shah': {'Snackible'},
#  'Anandbir Singh': {'Snackible'},
#  'Anirudh Sheth': {'Snackible'},
#  'Pratik Singhi': {'Snackible'},
#  'Vikram Mehta': {'Snackible'},
#  'Murali Nair': {'Snackible'},
#  'Gaurav Kachru': {'Be U Salons'},
#  'Sundeep Singh Sahni': {'Be U Salons'},
#  'Jatin Aneja': {'Babychakra', 'Be U Salons'},
#  'Arun Malhotra': {'Be U Salons'},
#  'Village Capital': {'Simulanis'},
#  'Anicut Capital': {'LendingKart'},
#  'IndiaNivesh Venture Capital Fund': {'Innefu Security Consulting'},
#  'Ideaspring Capital': {'Karomi', 'Lavelle Networks', 'Whodat'},
#  'Exfinity Venture Partners': {'Absentia VR',
#   'Fitternity',
#   'Iqlect',
#   'Locus',
#   'MarianaIQ',
#   'Shotang.com'},
#  'Undisclosed Investor': {'BlogBeats',
#   'Eat.Shop.Love',
#   'FoodTalkIndia',
#   'Frapperz',
#   'GoGo Truck',
#   'IOTrek',
#   'Intgrea',
#   'Kloseby',
#   'MuhurtMaza',
#   'Voxweb'},
#  'SIDBI Venture Capital Ltd': {'HolaChef', 'Pragmatix', 'Printland'},
#  'Ankit Nagori': {'Blinge', 'Flashdoor', 'Wooplr'},
#  'Ravi Garikipati': {'CareonGO', 'Makkajai', 'Video Ken'},
#  'Surot Chatterjee': {'Video Ken'},
#  'Ashish Agrawal': {'Video Ken'},
#  'LG Chandrasekhar': {'Video Ken'},
#  'Sashi Reddi': {'EureQa', 'Video Ken'},
#  'Ligthbox Ventures II': {'Faasos'},
#  'Lightbox Expansion Fund': {'Faasos'},
#  'Sequoia Capital India': {'Belong',
#   'DailyHunt',
#   'Faasos',
#   'FreshDesk',
#   'Grofers',
#   'HealthKart',
#   'Pocket Aces'},
#  'RuNet South Asia': {'Faasos'},
#  'SoftBank Vision Fund': {'Oyo'},
#  'Sequoia Capital India Advisors': {'Oyo'},
#  'Greenoaks Capital Partners': {'Oyo'},
#  'WGG International': {'Toppr'},
#  'pi Ventures': {'Niramai', 'Sigtuple', 'Zenatix'},
#  'Binny Bansal': {'HashLearn',
#   'Intelligent Interfaces',
#   'MadRat Games',
#   'Niramai',
#   'Pandorum Technologies',
#   'Roposo.com',
#   'SigTuple',
#   'UnaAcademy',
#   'Yumlane'},
#  'Arun Tadanki': {'Faircent', 'Indifi', 'The Office Pass'},
#  'Aditya Verma': {'The Office Pass'},
#  'DAH Beteiligungs GmbH': {'Flytxt'},
#  'S. Xavier Britto': {'Howdy Ventures'},
#  'Orios Ventures Partners': {'ZipGo'},
#  'Team Builder Ventures': {'ZipGo'},
#  'Omidyar Networks': {'RailYatri', 'ZipGo'},
#  'Agnus Capital': {'Customfurnish', 'Pastiwala', 'Scootsy'},
#  'Khattar Holdings': {'91SpringBoard', 'Scootsy'},
#  'GardX International': {'Autobix'},
#  'BlackSoil Capital Pvt. Ltd': {'iNurture'},
#  'Poshika Financial Ecosystem': {'Mintwalk'},
#  'SoftBank Group Corp': {'Ola'},
#  'Calcutta Angels Network (CAN)': {'Seenit'},
#  'Augment Ventures': {'Purple Style Labs', 'Seenit'},
#  'Vishwadeep Bajaj': {'Paalak'},
#  'Harsh Kundra': {'Paalak'},
#  'Nandkumar Rane': {'Paalak'},
#  'LN Buddharaju': {'Paalak'},
#  'Anupam Tyagi': {'Paalak'},
#  'Langoor': {'Kreate Konnect'},
#  'Quona Capital': {'CreditMantri'},
#  'Chandigarh Angels Network': {'JumboBasket',
#   'Lets Endorse',
#   'The Gourmet Jar'},
#  'Social Alpha and other unnamed angel investors': {'Lets Endorse'},
#  'Bhupen Shah': {'Tydy'},
#  'Jayesh Parekh': {'Tydy'},
#  'Sanjay Sathe': {'Tydy'},
#  'Sandeep Aggarwal': {'Nactus', 'Shopsity', 'Wydr'},
#  'Gautam Chhaochharia': {'Nactus'},
#  'R Balachandar': {'Nactus'},
#  'Bennett': {'Flipkart', 'Infibeam', 'Oho Shop'},
#  'Coleman and Company Ltd': {'Infibeam', 'Oho Shop'},
#  'Undisclosed angel investors': {'Emojifi'},
#  'Alibaba': {'Paytm', 'Snapdeal'},
#  'CDC Group Plc': {'iGenetics'},
#  'Atul Nishar': {'Avagmah', 'Juno Clinic', 'Nykaa'},
#  'Aneesh Seth': {'Summerlabel'},
#  'Tushar Mittal': {'Summerlabel'},
#  'SIDBI Venture Capital Fund': {'PickMe'},
#  'Star India Pvt Ltd': {'Zapr'},
#  'IDFC Parampara Early Stage Opportunities Fund': {'Data Resolve'},
#  'National Science and Technology Entrepreneurship Development Board': {'Book Servicing'},
#  'IDG Ventures India': {'Active.ai',
#   'Blowhorn',
#   'Cloudcherry Analytics',
#   'CreditMantri',
#   'FirstCry.com',
#   'HealthifyMe',
#   'Momoe',
#   'POPxo.com',
#   'PlaySimple',
#   'RentMojo',
#   'RentoMojo',
#   'Vserv',
#   'Xpressbees',
#   'Zimmber',
#   'iCrushiFlush'},
#  'Michael & Susan Dell Foundation': {'Avanti Learning',
#   'Blowhorn',
#   'Villgro',
#   'iStar Skill Development'},
#  'Draper Associates': {'Blowhorn'},
#  'Unitus Seed Fund': {'BetterPlace',
#   'Blowhorn',
#   'Caravan Craft',
#   'CueMath',
#   'Curiositi',
#   'DriveU',
#   'Jiffstore',
#   'LabInApp',
#   'OneClickWash',
#   'UE Life Sciences',
#   'UE LifeSciences',
#   'Urban Tailor',
#   'VillFarm',
#   'iMMi Life',
#   'iSTAR',
#   'iStar Skill Development'},
#  'Private Sector Banks (Debt Funding)': {'Rivigo'},
#  'IDG ventures': {'PipeCandy'},
#  'Y Combinator': {'RazorPay', 'Supr Daily'},
#  'SEGNEL Ventures': {'Parentune'},
#  'Deepak Gurnani': {'AppBrowzer'},
#  'Times Internet Ltd': {'Byju’s', 'Haptik', 'MagicBricks'},
#  'Singapore Angel Network': {'Babychakra',
#   'BookEventz',
#   'Boxmyspace',
#   'CareonGO',
#   'Endless Robotics',
#   'Explara',
#   'HashLearn',
#   'JustDoc',
#   'Ketto',
#   'SwitchMe',
#   'Vahdam Teas',
#   'iOrderFresh'},
#  'Asuka': {'PropertyShare'},
#  'Pravega Ventures': {'Fyle', 'PropertyShare'},
#  'BEENEXT': {'Get My Parking',
#   'Healthians',
#   'NoBroker',
#   'PropertyShare',
#   'Servify',
#   'Zefo'},
#  'Cyber Carrier': {'MyDermacy'},
#  'Florintree': {'LatestOne'},
#  'Chidambaram Palaniappan': {'LatestOne'},
#  'Bharat Sheth': {'LatestOne'},
#  'IDG Ventures': {'Aasaanjobs',
#   'Agrostar',
#   'Bizongo',
#   'CityFlo',
#   'CloudCherry',
#   'Curefit',
#   'Fintellix',
#   'Flyrobe',
#   'Hansel.io',
#   'Infisecure',
#   'LensKart',
#   'Lenskart',
#   'MyNoticePeriod',
#   'NestAway',
#   'Pluss',
#   'Sigtuple',
#   'Tripoto',
#   'Unbxd',
#   'Uniphore',
#   'mPaani'},
#  'Saha Fund': {'Fitternity', 'Gingercrush', 'mPaani'},
#  'Puneet Gupta': {'ShilpMIS', 'Yana'},
#  'Nimitt Desai & Others': {'ShilpMIS'},
#  'GREE Ventures': {'Flyrobe', 'POPxo'},
#  'Kalaari Capital and IDG Ventures India': {'POPxo'},
#  'Summit Media': {'POPxo'},
#  'Atul Goel': {'POPxo'},
#  'and Gurpreet Singh': {'POPxo'},
#  'Sujeet Kumar': {'Fitso', 'Flashdoor', 'Parentlane', 'Unacademy'},
#  'Bhupender Singh': {'Fitso'},
#  'Yashish Dhaiya': {'Fitso'},
#  'Microsoft': {'Flipkart'},
#  'eBay': {'Flipkart'},
#  'Rakesh and Rajesh Jhunjhunwala': {'Airpay'},
#  'L’Occitane': {'MyGlamm'},
#  'Shripad Nadkarni': {'Bonhomia', 'The Mons Co.'},
#  'Nandu Nandkishore': {'The Mons Co.'},
#  'Ravi Saxena': {'Haqdarshak'},
#  'Sandeep Raju': {'Haqdarshak'},
#  'Kinzon Capital': {'Ixigo'},
#  'FTV Capital': {'Markets and Markets'},
#  'Zodius Capital': {'Antuit',
#   'AppsDaily',
#   'Appsdaily',
#   'Culture Machine',
#   'FreshMenu',
#   'Markets and Markets'},
#  'Ojas Ventures': {'Bizom'},
#  'Mahavir Sharma': {'BabyonBoard'},
#  'Vishal Jain': {'BabyonBoard'},
#  'Rohit Sethi': {'BabyonBoard'},
#  'Gaurav Luniya': {'BabyonBoard'},
#  'Carlyle Group': {'Delhivery'},
#  'Tiger Global': {'Ather Energy',
#   'Caratlane.com',
#   'ChargeBee',
#   'Culture Machine',
#   'CultureAlley',
#   'Delhivery',
#   'Freshdesk',
#   'Grofers',
#   'Hike',
#   'LimeRoad.com',
#   'MoonFrog Labs',
#   'NestAway',
#   'Nestaway',
#   'News in shorts',
#   'NewsInShorts',
#   'Ola',
#   'PolicyBazaar',
#   'Quikr',
#   'Roposo',
#   'The Viral Fever',
#   'Zo Rooms',
#   'Zopper'},
#  'Vikas Bajaj': {'Sport Flashes'},
#  'Amit Kharbanda': {'Sport Flashes'},
#  '3one4 capital': {'Wigzo'},
#  'Brand Capital': {'AirMed Labs',
#   'CityFurnish',
#   'DoneThing',
#   'ExtraCarbon',
#   'Faircent.com',
#   'Gingercrush',
#   'Meru Cabs',
#   'NeoStencil',
#   'Quikr',
#   'SaleBhai',
#   'Simplilearn',
#   'iDreamCareer',
#   'icustommadeit'},
#  'Ankit Gupta': {'Ithaka'},
#  'Puneet Motihar': {'Ithaka'},
#  'KStart Capital': {'perpule'},
#  'Verlinvest': {'Byju’s'},
#  'Mayfield India': {'LendingKart',
#   'Licious',
#   'Securens',
#   'Simplilearn',
#   'Taskbob'},
#  '3one4 Capital': {'DarwinBox', 'DoSelect', 'Licious', 'Pocket Aces'},
#  'Sistema Asia Fund': {'Licious', 'Seclore', 'Wooplr'},
#  'Neoplux Technology Fund': {'Licious'},
#  'Vinod Martin': {'Medinfi'},
#  'Hemant Kaul': {'Medinfi'},
#  'Prof. Ram Kumar Kakani & Others': {'Medinfi'},
#  'JSW Ventures': {'Indus OS', 'Overcart.com', 'Purplle'},
#  'VenturEast': {'Indus OS'},
#  'Meher Roy': {'Emflux Motors'},
#  'Nikhil Arora': {'Emflux Motors'},
#  'Meet Kanodia': {'Emflux Motors'},
#  'Krit Sankalp': {'Emflux Motors'},
#  'Nitish Singh': {'Emflux Motors'},
#  'Risabh Gupta': {'Emflux Motors'},
#  'Om Chaudhry': {'Klinic App'},
#  'Malini Patel': {'Jhakaas'},
#  'Stelcore Management Services': {'Jhakaas'},
#  'Anjani Prasad': {'Jhakaas'},
#  'Samridhi Fund': {'Oriano Solar'},
#  'Intex Technologies': {'Rooter'},
#  'Satveer Thakral': {'FalconBrick'},
#  'Mumbai Angels': {'AppsDaily',
#   'Azuro',
#   'Babychakra',
#   'Betaout',
#   'BookEventz',
#   'DoSelect',
#   'FalconBrick',
#   'Fitpass',
#   'Frsh',
#   'Gingercrush',
#   'Joy by nature',
#   'Massblurb',
#   'MintM',
#   'Register My Marriage',
#   'Unocoin',
#   'Wittyparot'},
#  'B Capital Group': {'Icertis'},
#  'Ignition Partners': {'Icertis'},
#  'Greycroft': {'Icertis'},
#  'e.ventures': {'CupoNation', 'Icertis'},
#  'Satya D Sinha': {'Stockroom.io'},
#  'Gyanendra Singh': {'Stockroom.io'},
#  'IFMR Capital Finance': {'Capital Float'},
#  'Jaarvis Accelerator': {'iManageMyHotel'},
#  'Batlivala & Karani Securities': {'Glamrs', 'Inner Hour'},
#  'Venture Works': {'Inner Hour', 'Overcart.com'},
#  'Earlsfield Capital': {'Prozo', 'Stelae', 'Wandertrails'},
#  'Temasek Holdings': {'CarTrade', 'Cartrade'},
#  'Japan Vyas': {'MindYourFleet'},
#  'Tarun Adlakha': {'MindYourFleet'},
#  'Facebook FB Start programme': {'Edurev'},
#  'Ganesh Natarajan': {'1Crowd', 'Coppre'},
#  'Amereus Group': {'Wooplr'},
#  'Helion Ventures': {'LivSpace',
#   'Livspace',
#   'RailYatri',
#   'Simplilearn',
#   'Toppr',
#   'Wooplr',
#   'Zefo'},
#  'Al Dhaheri family': {'48East'},
#  'ThinQbate': {'Redesyn'},
#  'VH Capital': {'Sigtuple'},
#  'Axilor Partners': {'Sigtuple'},
#  'Lumis Partners': {'Altizone', 'Flutura', 'Sheroes'},
#  'Anil Jain & other HNIs': {'Wassup'},
#  'Kleiner Perkins': {'Better Mortgage'},
#  'Pine Brook': {'Better Mortgage'},
#  'Mohit Joshi & Others': {'Nurturey'},
#  'Mahalingam K': {'GoBumpr'},
#  'Vikram Sud': {'Connaizen', 'Flexiloans'},
#  'Punit Soni': {'Innov8', 'Razorpay'},
#  'Utsav Somani': {'Innov8', 'Truce'},
#  'Vishal Gondal': {'InnerChef', 'Innov8', 'Remitr'},
#  'Vikram Limaye': {'Innov8'},
#  'PayU': {'Zest Money', 'ZestMoney'},
#  'Ribbit Capital': {'PolicyBazaar', 'ZestMoney'},
#  'Quake Capital': {'AirZaar'},
#  'Kalaari Capital Partners': {'YourStory'},
#  'Qualcomm': {'Housejoy', 'YourStory'},
#  '3ONE4 Capital Advisors': {'YourStory'},
#  'UC-RNT': {'YourStory'},
#  'SRI Capital': {'Imaginate',
#   'NumberMall',
#   'WorkApps',
#   'Yellowdig',
#   'Zuppler'},
#  'Aprameya Radhakrishna': {'Cartisan',
#   'Daily Ninja',
#   'DailyNinja',
#   'Dazo',
#   'Fisdom',
#   'TapChief',
#   'The Ken',
#   'Unacademy',
#   'Vyomo',
#   'YourDOST',
#   'iService',
#   'm.paani'},
#  'Deepak Natraj': {'The Ken'},
#  'Mahesh Murthy': {'NewsLaundry', 'The Ken'},
#  'Pavan Ongole': {'Fastudent', 'The Ken', 'YourDOST'},
#  'Sandeep Mathur': {'The Ken'},
#  'Vijay Shekhar Sharma & Others': {'The Ken'},
#  'Steadview Capital': {'Ola', 'Quikr', 'Saavn', 'Urban Ladder'},
#  'Konglo Ventures': {'Aisle', 'CareonGO'},
#  'White Unicorn Ventures': {'Aisle', 'Azuro'},
#  'BookMyShow': {'TownScript'},
#  'Facebook FBStart': {'Blood n Care', 'Leopetra', 'Vebbler'},
#  'Coleman and Co. Ltd (BCCL)': {'Flipkart'},
#  'Softbank Ventures Korea': {'True Balance'},
#  'IMM Investment': {'True Balance'},
#  'Indian Angel Network (IAN)': {'Get My Parking', 'Uniphore'},
#  'Sunil Munjal': {'Get My Parking', 'Nykaa'},
#  'Nitin Saluja': {'Lets Reap'},
#  'Gagan Goyal': {'Lets Reap'},
#  'Pankaj Rungta': {'Oglas'},
#  'Yogesh Agarwal': {'Oglas'},
#  'Ishan Manaktala': {'Staydobe'},
#  'Chandigarh Angels': {'Biryani By Kilo'},
#  'Rohit': {'Biryani By Kilo'},
#  'Ashish Chand': {'Biryani By Kilo'},
#  'Sunil Singh & Others': {'Biryani By Kilo'},
#  'Paragon Trust': {'NeoStencil'},
#  'Sands Capital': {'Blackbuck'},
#  'IFC': {'Blackbuck', 'NxtGen'},
#  'Flipkart': {'BlackBuck',
#   'Blackbuck',
#   'Cube26',
#   'FXMartIndia',
#   'Mech Mocha',
#   'Nestaway',
#   'QikPod',
#   'TinyStep',
#   'Zapr',
#   'Zinka'},
#  'Sanjiv Rangrass': {'Blackbuck'},
#  'V Balakrishnan': {'Clonect Solutions', 'TaxSutra'},
#  'PV Srinivasan': {'TaxSutra'},
#  'K2 Capital': {'TempoGo'},
#  'Rajiv Mehta': {'GoFynd', 'SmartPocket', 'Wooplr'},
#  'Ramakant Sharma': {'GoFynd', 'TruckMandi'},
#  'Vishal Malik': {'Vow Car Clinic'},
#  'DanGold Investment Corp': {'MobiDent'},
#  'Marico Innovation Foundation (MIF)': {'Yostra'},
#  'Villgro': {'Vahan', 'Yostra'},
#  'India Nivesh Growth Fund': {'Leap India'},
#  'Sixth Sense': {'Leap India'},
#  'TCI Ventures': {'Leap India'},
#  'Jasper Infotech Pvt Ltd': {'FreeCharge'},
#  'Alibaba Pictures': {'TicketNew'},
#  'BlackSoil Capital Pvt Ltd': {'Intelligence Node'},
#  'Vedanta Capital': {'Loan Frame'},
#  'William Campbell': {'Loan Frame'},
#  'Toos N Daruvala': {'Loan Frame'},
#  'Aavya Ventures': {'DriveSkool'},
#  'Evan Lim': {'Medinfi'},
#  'Kanchan Ghoshal': {'Medinfi'},
#  'Ram Kumar Kakani': {'Medinfi'},
#  'Ronnie Screwvala': {'LensKart'},
#  'Zishaan Hayath': {'BookEventz',
#   'Flyrobe',
#   'InstaOffice',
#   'LoanCircle',
#   'Orobind',
#   'Pickingo',
#   'ShadowFax',
#   'SquadRun',
#   'Wealthy'},
#  'Karan Chellani': {'InstaOffice', 'SatvaCart'},
#  'Mohit Satyan': {'InstaOffice'},
#  'Lohia Group': {'Square Yards'},
#  'Andre Hoffman': {'Square Yards'},
#  'Deutsche Telekom Strategic Investments & Others': {'Roambee'},
#  'Vividhity Ventures': {'PaisaWapas'},
#  'Parampara Early Stage Opportunities Fund & Others': {'SecururAX'},
#  'Harsh V. Pant': {'Leadburg'},
#  'Ratheesh Raveendran': {'Leadburg'},
#  'Innoven Capital': {'MobiKwik', 'Peppertap', 'Ridlr', 'ZoloStays'},
#  'Quarizon': {'Asocon',
#   'Chai Thela',
#   'Oi Media',
#   'Pictor Imaging',
#   'Streo',
#   'TripShelf'},
#  'Menterra Social Impact Fund': {'Curiositi', 'Math Buddy'},
#  'Tencent': {'Practo'},
#  'ru-Net': {'AppDaily', 'CupoNation', 'Faasos', 'Practo'},
#  'RSI Fund': {'Practo'},
#  'Thrive Capital': {'Practo'},
#  'India Quotient and others': {'Ketchupp'},
#  'Ajith Nair': {'Ezytruk', 'Tiyo'},
#  'Anish K': {'Ezytruk'},
#  'Amajit Gupta': {'Kratikal'},
#  'Praveen Dubey': {'Kratikal'},
#  'J.P. Bhatt': {'Kratikal'},
#  'Rajasthan Venture Capital Fund': {'Direct Create'},
#  'Mumbai Angels Network': {'Vahdam Teas'},
#  'SB Ventures': {'PParke'},
#  'Native Angels Network': {'Native Special'},
#  'SD Group': {'Fitnapp'},
#  'Jungle Venture Partners': {'Wydr'},
#  'IvyCamp Ventures': {'Mr Hot Foods', 'Tyre Express'},
#  'Umang Moondra': {'Connaizen'},
#  'Undisclosed investor': {'Dipper',
#   'First Eat',
#   'Gomalon',
#   'HealthKumbh',
#   'KabadiExpress',
#   'MessaGif',
#   'OrangeTwig',
#   'Shouut',
#   'vImmune'},
#  'Singapore based investor': {'SmartHi'},
#  'YourNest Fund II': {'CRON Systems'},
#  'CapitalG': {'CueMath'},
#  'India Educational Investment Fund': {'ChipperSage',
#   'Oliveboard',
#   'ReportBee',
#   'SelectJobs'},
#  'Indochine International': {'Khel Now'},
#  'Iron Pillar and IIFL': {'NowFloats'},
#  'GMO Japan': {'Lets Transport'},
#  'Neelesh Bhatnagar': {'Lets Transport'},
#  'East Ventures & Others': {'BetaOut'},
#  'Alok Mittal & others': {'Wishberry'},
#  'Senovo': {'LoyaltyPrime'},
#  'Unternehmertum Venture Capital': {'LoyaltyPrime'},
#  'Alexander Bruehl': {'LoyaltyPrime'},
#  'ABM Knowledgeware': {'InstaSafe'},
#  'Dream Incubator': {'99Games'},
#  'V Aanand R': {'99PerHour'},
#  'Puthen & Cole': {'Kochi Post'},
#  'Sanjay Mehta & Others ( The Ten Minute Million)': {'Intuit Things'},
#  'The Ten Minute Million': {'Cloudrino', 'FabX', 'Maptags'},
#  'Chandigarh Angels Network (CAN)': {'YOLO Health'},
#  'Grace Capital Ventures': {'ONN Bikes', 'SidQam'},
#  'Soham Vencaps': {'SidQam'},
#  'American Express Ventures': {'HelpChat', 'India Lends'},
#  'Cyber Carrier VC': {'India Lends'},
#  'AdvantEdge Partners': {'India Lends', 'Rapido', 'Smartivity'},
#  'Songhyun Investment': {'Slide App'},
#  'Undisclosed': {'360Ride',
#   'Badiyajobs',
#   'Briston Technomach',
#   'ICHR',
#   'Newspatrolling',
#   'Smartairtrip.com',
#   'Streamoid',
#   'WickedRide',
#   'ePoise'},
#  'GEMs Advisory': {'Streo'},
#  'Franchise India': {'TYGR', 'UClean'},
#  'Lakshmi Vilas Bank & undisclosed HNIs': {'UrDoorStep'},
#  'Info Edge (India)': {'Diro Labs', 'Zomato'},
#  'Ajith Sukumaran': {'THB'},
#  'Currae Healthtech Fund': {'LetsMD', 'PharmaRack', 'THB'},
#  'Eros Labs': {'Alternacare', 'LookAtMe'},
#  'Investors from Mumbai Angels & LetsVenture': {'BookEventz'},
#  'Mohan Kumar': {'Tailslife'},
#  'V. Balakrishnan': {'Tailslife'},
#  'Edelweiss Private Equity': {'BRIDGEi2I', 'Freshee', 'Revv'},
#  'Venk Krishnan': {'Daily Ninja', 'TapChief', 'WealthApp', 'YourDOST'},
#  'MJ Aravind': {'WealthApp'},
#  'Vikram Kotak': {'WealthApp'},
#  'Jayant Davar': {'WealthApp'},
#  'Ramkumar Nishtal': {'WealthApp'},
#  'Arjun Sharmaa': {'WealthApp'},
#  'Calcutta Angel Network': {'Vehico'},
#  'Appliyifi': {'Vehico'},
#  'Max Ventures and Industries': {'Nykaa'},
#  'Verlinvest SA': {'Xseed Education'},
#  'Axilor': {'UrbanPiper'},
#  'Siddhartha Gupta': {'Fresh Food Concepts'},
#  'Ashvin Chadha': {'Burger Singh',
#   'Fresh Food Concepts',
#   'Gadgetwood',
#   'Lendingkart',
#   'Zappfresh'},
#  'Rajul Garg': {'Babygogo',
#   'Fashalot',
#   'GoComet',
#   'LifCare',
#   'Meesho',
#   'Sheroes',
#   'The Uolo'},
#  'Rajesh Yabaji': {'GoComet'},
#  'Chanakya Hridaya': {'GoComet'},
#  'Ramasubramaniam B': {'GoComet'},
#  'Vishwanathan': {'GoComet'},
#  'Nobel House': {'GoComet'},
#  'Sunstone Capital': {'GoComet'},
#  'Zodius Technology Opportunities Fund': {'AppDaily', 'OfBusiness'},
#  'FiNC': {'Fitmein'},
#  'GHV': {'Fitmein'},
#  'Lead Angels Network': {'Qacco'},
#  'Anbu Pandian': {'BookEventz', 'Qacco'},
#  'Prabhakar MR & Others': {'Qacco'},
#  'V. Krishna Prasad': {'Ten3t Health'},
#  'Bhupen Shah & Others': {'Ten3t Health'},
#  'Swastika Investmart Ltd': {'Trading Bells'},
#  'Digital Financial Service Lab': {'SERV’D'},
#  'WRV Capital and IndusAge Partners': {'IdeaForge'},
#  'Infosys Innovation Fund': {'IdeaForge'},
#  'Emerald Media': {'Amagi Media Labs', 'Yupp TV'},
#  'Premji Invest': {'Amagi Media Labs'},
#  'North Base Media': {'Funcastic', 'Pocket Aces'},
#  'Aarin Capital': {'Campus Diaries',
#   'DoSelect',
#   'Impact Analytics',
#   'Magic Crate',
#   'Oust App',
#   'Pocket Aces',
#   'UE Life Sciences'},
#  'Epsilon Venture Partners': {'Pi Data Centers'},
#  'GEMS Advisory': {'TripShelf'},
#  'KTB Network': {'NoBroker'},
#  'Cyber Carrier CL': {'Zoomcar'},
#  'International Financial Corporation': {'BYJU’s'},
#  'Dr. Apoorv Ranjan Sharma': {'ConfirmTKT', 'Supr Daily'},
#  'Anil Jain': {'Supr Daily'},
#  'Anuj Golecha': {'Supr Daily'},
#  'Krishna Jhunjhunwala': {'Supr Daily'},
#  'Anirudh Damani': {'ConfirmTKT',
#   'FindUrClass',
#   'Jusride',
#   'LenDenClub',
#   'Supr Daily',
#   'Vahanalytics'},
#  'Let’s Venture': {'The BlueBook'},
#  'Fireside Ventures & Others': {'MamaEarth'},
#  'HCS Venture capital fund': {'Innoplexus'},
#  'Taxmann': {'Mindler'},
#  'Kaushal Agarwal': {'MCaffeine'},
#  'Harminder Sahani': {'MCaffeine'},
#  'KK Mehra': {'MCaffeine'},
#  'Pranay Jivrajka': {'MCaffeine', 'WitWorks'},
#  'Navjot Saini': {'MCaffeine'},
#  'Ivy League Alumni Angel Network': {'enKast'},
#  'Incubate Fund': {'ShopKirana'},
#  'Lead Angels Group & Others': {'ShopKirana'},
#  'Pradyumna Dalmia': {'Ketto', 'MyAdvo'},
#  'S. Somasegar & Others': {'MyAdvo'},
#  'Ritesh Mehta': {'The Postbox'},
#  'Aruna Ganesh Ram': {'The Postbox'},
#  'Sachin Bansal': {'Intelligent Interfaces',
#   'Pandorum Technologies',
#   'SigTuple',
#   'Tracxn',
#   'UnaAcademy'},
#  'Lead Angels': {'Belita',
#   'BookEventz',
#   'GameXS.in',
#   'MyCuteOffice',
#   'Timemytask'},
#  'CoCreate Ventures': {'Justbooks'},
#  'Kaleden Holdings': {'InstantPay'},
#  'Kedar Lele': {'PickMyLaundry'},
#  'GHV Accelerator': {'Applop', 'PickMyLaundry'},
#  'Calcutta Angels Network': {'LetsMD', 'ZeroInfy'},
#  'Raman Roy': {'PicsDream', 'Sattviko'},
#  'Yogesh Andlay': {'Sattviko'},
#  'Vaibhav Jain': {'Sattviko'},
#  'Gati Ltd': {'Browntape'},
#  'Aavishkaar Venture Management': {'Connect India'},
#  'Ameera Shah': {'Awesummly', 'Corseco', 'infeedo'},
#  'A M Sikander': {'Medzin'},
#  'Warburg Pincus': {'Capillary Tech', 'CarTrade', 'Ecom Express', 'Rivigo'},
#  'Justin Kan': {'JustRide'},
#  'Qasar Younis': {'JustRide'},
#  'Paul Bucche': {'JustRide'},
#  'Susa Ventures': {'JustRide'},
#  'Kima Ventures': {'JustRide'},
#  'Axan Venture': {'JustRide'},
#  'SCM Holdings': {'JustRide'},
#  'ADAG Reliance Private Equity': {'Square Yards'},
#  'YourNest Angel Fund': {'Aahaa',
#   'Arya.ai',
#   'Bestdealfinance',
#   'Fashalot',
#   'GolfLAN',
#   'MoMark',
#   'MyCity4Kids',
#   'Simpli5d',
#   'TheSmartQ',
#   'Uniphore'},
#  'iSON': {'GolfLAN'},
#  'Gleevoaz Ventures': {'Yottaasys'},
#  'Arun Seth': {'Tone Tag'},
#  'T.V. Mohandas Pai': {'Tone Tag'},
#  'Deepak Ghaisas': {'Tone Tag'},
#  'RTP-HC': {'Stasis Labs'},
#  'Wonder Ventures': {'Stasis Labs'},
#  'Techstars Ventures & Others': {'Stasis Labs'},
#  'Pramod Bhasin': {'Indifi',
#   'NDTV ecommerce venture',
#   'Scienaptic',
#   'Smartcooky'},
#  'Times of India Group & Existing investors': {'Koovs'},
#  'R.S Sharma': {'Trip Tap Toe'},
#  'Omnivore Capital': {'GramCover'},
#  'Hitesh Windlass': {'AerMed'},
#  'Devdeep Singh': {'Bats on delivery'},
#  'Khosla Impact': {'Lookup', 'NeoGrowth', 'numberz.in'},
#  'Softbank Group': {'Housing.com'},
#  'YMS Mobitech': {'VoLT'},
#  'Sanjai Vohra': {'ShubhLoans'},
#  'V. Bunty Bohra': {'ShubhLoans'},
#  'Undisclosed multiple investors': {'Noddapp'},
#  'Delta Partners': {'Knowlarity'},
#  'Blacksoil': {'Knowlarity'},
#  'Lightspeed Venture Partners India': {'Udaan'},
#  'Lightspeed US': {'Udaan'},
#  'Dr. Pooja Gandhi': {'FroyoFit'},
#  'Barkawi Holdings GmbH': {'Servify'},
#  'TM Service Technology Holdings Gmbh': {'Servify'},
#  'Sreevathsa Prabhakar': {'Servify'},
#  'VC Karthic': {'Hubilo'},
#  'Miten Mehta': {'Hubilo'},
#  'Umasankar Nistala': {'Hubilo'},
#  'Rakesh Patel': {'Hubilo'},
#  'Akash Bhavsar': {'Hubilo'},
#  'Jeevanandhan Rajagopal': {'Hubilo'},
#  'Vikas Chadha & Others': {'Hubilo'},
#  'Reliance Entertainment': {'FunOnGo'},
#  'Subramanya Venkat': {'Parentlane', 'TapChief'},
#  'Manish Maheshwari': {'WholeSaleBox'},
#  'Contrarian Vriddhi Fund': {'WholeSaleBox'},
#  'Mohit Sharma': {'Crossahead'},
#  'Silver Range Investments': {'HandyTrain'},
#  'Lumina Datamatics': {'HandyTrain'},
#  'Shun Yoshida & Others': {'HandyTrain'},
#  'Yang Shu': {'ShopsUp'},
#  'Shekhar Sahu': {'Indofash'},
#  'Nitesh Pant': {'Indofash'},
#  'Dileep Bhatt': {'Entropika'},
#  'Milind Chaudhary': {'Entropika'},
#  'Krishna Rokhale': {'Interviewpad'},
#  'Blume Ventures & Others': {'MonkeyBox', 'Tricog'},
#  'TVS Group': {'Carcrew.in', 'Industrybuying'},
#  'Mahindra Univeg': {'MeraKisan'},
#  'Recruit Holdings': {'Mystifly'},
#  'Viraj Tyagi & Others': {'World Art Community'},
#  'Mahindra Holidays & Resorts India Ltd': {'Giftxoxo'},
#  'BeeNext': {'Bharat Bazaar', 'GoZefo', 'Locus'},
#  'Naveen Arya': {'India Gifts Portal'},
#  'Tarun Joshi': {'India Gifts Portal'},
#  'SeedPlus': {'Appknox', 'Moglix'},
#  'Xchange Investors NV': {'NetLinx'},
#  'TransGlobal FZC': {'NetLinx'},
#  '3One4 Capital': {'Scandid'},
#  'Pravin Gandhi': {'Remitr'},
#  'Smart Start Fund; Kunal Shah': {'Remitr'},
#  '& Others': {'Remitr'},
#  'Russian venture capital fund Ru-Net': {'AppsDaily'},
#  'Healthsquad': {'NeuroSynaptic'},
#  'Ventureast Fund Advisors': {'FindmeaShoe'},
#  'Sumpoorna Group': {'Sportido'},
#  'HAX Accelerator': {'RayIOT'},
#  'HDFC': {'KOOH Sports'},
#  'Faering Capital': {'FundsIndia.com', 'KOOH Sports'},
#  'Elevate Sports': {'KOOH Sports'},
#  'Sanjay Nayar': {'Flexiloans'},
#  'Anil Jaggia': {'Flexiloans'},
#  'Narayan Seshadri': {'Flexiloans'},
#  'Radhakrishnan Natarajan & Others': {'Sibia Analytics'},
#  'undisclosed investor': {'Bombay Shirt Company', 'Skoov.com', 'Vithi.com'},
#  'Nitin Passi': {'Deyor Camps'},
#  'Manickam Mahalingam': {'Deyor Camps'},
#  'Udaan Angels': {'Burger Singh', 'Deyor Camps'},
#  'Rajesh Arora': {'Deyor Camps'},
#  'Arkas Industries': {'Deyor Camps'},
#  'Arun Venkatachalam': {'Industrybuying', 'ZipLoan'},
#  'Badal Malick': {'DayBox', 'ZipLoan'},
#  'FAO Ventures': {'FabAlley'},
#  'Tushar Singh': {'FabAlley'},
#  'Ranjan Sharma': {'FabAlley'},
#  'Virendra Patel': {'RoboVac'},
#  'Gray Matters Capital': {'Address Health', 'ISFC', 'Liqvid'},
#  'Quarizon Consultancy Services LLP': {'BeatRoute'},
#  'Karan Bhagat': {'Kidsstoppress'},
#  'ByteDance': {'DailyHunt'},
#  'Arun Sarin': {'DailyHunt'},
#  'Falcon Edge': {'DailyHunt'},
#  'Mayank Shah': {'MyKindofJob'},
#  'Shreyans Shah': {'MyKindofJob'},
#  'Vishnu Bhat': {'Trilyo'},
#  'Rajiv Lunkad': {'Trilyo'},
#  'Naresh Ravindranath': {'Trilyo'},
#  'Boman Irani': {'Rooter'},
#  'Dhruv Chitgopekar': {'Rooter'},
#  'Prantik Dasgupta': {'Rooter'},
#  'Hemant Sahni': {'Yumigo'},
#  'Bravia Capital': {'Rentalpha'},
#  'Newbie Promoters': {'3Dexter'},
#  'General Catalyst Partners': {'MySUN'},
#  'TLabs': {'ePathsala'},
#  'Lightbox Ventures': {'Droom.in', 'Faasos', 'Faaso’s', 'Furlenco', 'Melorra'},
#  'Axis Capital & Others': {'Furlenco'},
#  'Saama Capital': {'EazyDiner',
#   'Fisdom',
#   'LendingKart',
#   'Lendingkart',
#   'Sminq',
#   'Vistaar Finance'},
#  'Raghunandan G': {'BHIVE',
#   'Fisdom',
#   'Galleri5',
#   'JustDoc',
#   'Touchkin',
#   'Wooplr'},
#  'Next Orbit Ventures Fund': {'Actofit'},
#  'Ranjan Pai': {'HomeLane', 'Stayology'},
#  'Mobikon': {'Hipcask'},
#  'Blume ventures': {'RailYatri'},
#  'Janak Jain': {'ChatOnGo'},
#  'KAE capital': {'WOTU'},
#  'IIFL Seed Ventures Fund': {'Box8'},
#  'Mayfield Ventures': {'Box8', 'LEAP India', 'Simplilearn', 'Triphobo'},
#  'Swastika Company Ltd': {'Makkajai', 'Pickrr', 'Pocketin', 'Qlivery'},
#  'Lalit Vase': {'SooperMO'},
#  'Astarc Ventures': {'Absentia', 'Rapido', 'Renderlogy', 'Wooplr'},
#  'hooting Starts Sports LLP': {'The Kettlery'},
#  'Franchise India Brands': {'The Kettlery'},
#  'Eureka Forbes Ltd': {'Idea Bubbles'},
#  'Shapoorji Pallonji & Co. Ltd.': {'Idea Bubbles'},
#  'Omnivore Partners': {'FR8', 'Retigence Technologies'},
#  'Hero MotoCorp': {'Ather Energy'},
#  'Ajay Nanavati': {'Pikkol'},
#  'Afsal Salu': {'DailyNinja', 'Pikkol'},
#  'Michael Herzig': {'Impact Analytics'},
#  'Ashish Lakhanpal': {'Impact Analytics'},
#  'Karanpal Singh & Others': {'Talent Next'},
#  'Exfinity Ventures': {'Mad Street Den', 'MoEngage', 'Uniken'},
#  'growX ventures': {'Biteclub', 'Locus', 'Mad Street Den'},
#  'Pradeep Dhobale': {'Renowala'},
#  'Amit Choudhary': {'Cloudacar', 'Lucideus'},
#  'Grasshoppers': {'Trackbizz'},
#  'Anita Dongre': {'Social Quotient'},
#  'Yash Dongre': {'Social Quotient'},
#  'Milind Sarwate': {'Social Quotient'},
#  'William Bissel': {'Stalk Buy Love'},
#  'Infina Finance Pvt. Ltd': {'eShakti'},
#  'PremjiInvest': {'Lenskart', 'PolicyBazaar'},
#  'Venturra Capital': {'Zilingo'},
#  'Susquehanna International Group.\xa0 Wavemaker Partners': {'Zilingo'},
#  'InnoVen Capital India': {'Simplilearn'},
#  'Sailender Solanki': {'Prozo'},
#  'Rajiv Solanki': {'Prozo'},
#  'CareerNet Consulting Pvt. Ltd': {'TopRankers'},
#  'Ideation Initiative Pvt. Ltd': {'TopRankers'},
#  'Idein Ventures': {'BuildTraders', 'Infurnia', 'Qriyo', 'REstate'},
#  'Chan Zuckerberg Initiative': {'Byju’s'},
#  'Sofina': {'Byju’s', 'Paper Boat', 'practo'},
#  'Lightspeed Ventures': {'Byju’s',
#   'Craftstvilla',
#   'OneAssist',
#   'Phone Warrior'},
#  'Ravi Linganuri': {'Freshboxx'},
#  'Dr. Rameshwar Kumar': {'CureInstant'},
#  'havya Sharma': {'Poshtic'},
#  'Amit Nagar': {'Poshtic'},
#  'Harinder Takhar': {'KarmaCircles'},
#  'Zain Raj': {'KarmaCircles'},
#  'Dr. Prasad Kaipa': {'KarmaCircles'},
#  'Abaran Deep': {'KarmaCircles'},
#  'Aseem Sood': {'KarmaCircles'},
#  'Mustafa Patni': {'KarmaCircles'},
#  'Rahul Kayan': {'Purple Style Labs'},
#  'Nikhil Golcha': {'Purple Style Labs'},
#  'Shubham Gupta': {'Purple Style Labs'},
#  'Roy Kwan': {'Purple Style Labs'},
#  'Fork Media': {'Inuxu'},
#  'Mariwala family': {'Nykaa'},
#  'Pradeep Mirani': {'Glam Studios'},
#  'Aqeel Ahmed': {'Glam Studios', 'GlamStudios'},
#  'Anand Ladsariya': {'ConfirmTKT', 'Glam Studios'},
#  'Nitin Agarwal': {'Glam Studios'},
#  'Raj Singh Bhandal': {'Findow'},
#  'BlackSoil Capital Pvt. Ltd.': {'NearBuy'},
#  'Balasubramanian Krishnamurthy': {'Flocareer'},
#  'Sidhartha Hazarika & Others': {'Flocareer'},
#  'Scadea Solutions Inc': {'LensPick'},
#  'Dheeraj Jain': {'Burger Singh', 'LifCare', 'Qdesq', 'ShaadiSaga', 'infeedo'},
#  'Palash Jain': {'infeedo'},
#  'Rahul Singh': {'infeedo'},
#  'Ambarish Gupta': {'infeedo'},
#  'Lightbox Ventures and others': {'Furlenco'},
#  'Ganesh Narasimhan': {'NewsDistill'},
#  'Ramana Thumu': {'NewsDistill'},
#  'Sudhir Mallem': {'NewsDistill'},
#  'CIO Angel Network': {'Codemojo', 'Paytunes'},
#  'Sumit Jain': {'BaggOut',
#   'Dazo',
#   'JoeHukum',
#   'Parentlane',
#   'Sattviko',
#   'Unacademy'},
#  'KellyGamma': {'PurpleDocs'},
#  'Lead Angels & Others': {'CarveNiche', 'PurpleDocs'},
#  'Goldman Sachs Group': {'Pepperfry'},
#  'Zodius Technology Fund': {'Allygrow Technologies',
#   'FreshMenu',
#   'Pepperfry',
#   'Zivame'},
#  'Lothal Angel Ventures': {'eQuickies'},
#  'Anglian Omega Network': {'Khel Now', 'lehlehsports'},
#  'Akusa Holdings': {'DailyRounds'},
#  'Rebright Partners': {'DocsApp',
#   'Elanic',
#   'Flixy Games',
#   'LetsTransport',
#   'NewsInShorts',
#   'Reach'},
#  'Cisco Ventures': {'CloudCherry'},
#  'Rohit MA': {'Parentlane'},
#  'Idea Wave Labs': {'First Moms Club'},
#  'Prashant Tandon': {'JoeHukum', 'Near.in', 'inMotion'},
#  'Gaurav Agarwal': {'Houssup', 'Near.in', 'inMotion'},
#  'Gaurav Bhogle': {'inMotion'},
#  'Shrishti Sahu': {'inMotion'},
#  'Shantanu Mathur': {'inMotion'},
#  'Prabhat Aggarwal': {'inMotion'},
#  'Scale Ventures Funds': {'Let’s Barter'},
#  'Procam International Pvt. Ltd': {'EvenGini'},
#  'Flipkart Logistics Pvt. Ltd': {'TinyStep'},
#  'Pratik Seal': {'Canvs'},
#  'Swastika Co Ltd.': {'Instacar'},
#  'EDBI': {'Druva'},
#  'Blue Cloud Ventures': {'Druva'},
#  'Hercules Capital': {'Druva'},
#  'Now Capital': {'Promon'},
#  'Kanwaljit Singh': {'Bonhomia', 'Buttercups', 'Fastudent', 'Licious'},
#  'Ajay Lakhotia': {'Fastudent'},
#  'ah! Ventures': {'AHA Taxis',
#   'Aisle',
#   'Bluegape',
#   'Bluegape.com',
#   'DriversCart',
#   'Eywa Media',
#   'Ketto',
#   'ORIGA Leasing',
#   'ShaadiSaga',
#   'ShabdNagari',
#   'Shirsa Labs',
#   'Unocoin',
#   'iDreamCareer',
#   'iTraveller.com'},
#  ...}

# %%
investor = {}
for key in Dict:
    if key == "":
        continue
    investor[key] = len(Dict[key])

# %%
# stored investors in X-list who have invested In  different companies by Dict.keys
# stored values of invested maximum number of times in different companies
# for each investor by Dict.values
x = list(investor.keys())
y = list(investor.values())

np_x = np.array(x)
np_y = np.array(y)

np_x = np_x[np.argsort(np_y)]
np_y  = np.sort(np_y)

# extact top 5 investors who have invested maximum number of times in different companies startup
np_x = np_x[len(np_x)-1: len(np_x) -1-5 : -1]
np_y = np_y[len(np_y)-1: len(np_y) -1-5 : -1]

# plot line graph between top 5 investors and 
# thair invested maximum number of times in different companies startup
plt.plot(np_x, np_y, "o--")
plt.grid()
plt.xticks(rotation = 40)
plt.show()

# plot a pie graph 
plt.pie(np_y, labels = np_x, autopct = "%.2f%%")
plt.show()

for i in range(len(np_x)):
    print(np_x[i], np_y[i])
# Out:
# Sequoia Capital 47
# Accel Partners 47
# Kalaari Capital 41
# Indian Angel Network 40
# Blume Ventures 36

# %% [markdown]
# # 4- Question
# Even after putting so much effort in finding the probable investors, it didn't turn out to be helpful for your friend. So you went to your investor friend to understand the situation better and your investor friend explained to you about the different Investment Types and their features. This new information will be helpful in finding the right investor. Since your friend startup is at an early stage startup, the best-suited investment type would be - Seed Funding and Crowdfunding. Find the top 5 investors who have invested in a different number of startups and their investment type is Crowdfunding or Seed Funding. Correct spelling of investment types are - "Private Equity", "Seed Funding", "Debt Funding", and "Crowd Funding". Keep an eye for any spelling mistake. You can find this by printing unique values from this column. There are many errors in startup names. Ignore correcting all, just handle the important ones - Ola, Flipkart, Oyo and Paytm.

# %%
# drop null values from InvestmentType column 
df.drop(df.index[df.InvestmentType.isnull()], inplace = True )
# reset index
df.reset_index(inplace = True, drop = True)

# handle spelling mistakes
df.loc[df.InvestmentType == 'PrivateEquity', 'InvestmentType'] = "Private Equity"
df.loc[df.InvestmentType == 'SeedFunding', 'InvestmentType'] = "Seed Funding"
df.loc[df.InvestmentType == 'Crowd funding', 'InvestmentType'] = "Crowd Funding"

np_investor = np.array(df.InvestorsName, dtype = 'str')

# create investors list of all the investors who have invested in a different companies and
# their investment type is a Private Equity 
investors = []
for i in range(len(np_investor)):
    if df['InvestmentType'][i] == "Private Equity":
        if 'Undisclosed' not in np_investor[i] or 'undisclosed' in np_investor[i]:
            if "," in np_investor[i]:
                val = np_investor[i].split(',')
                for name in val:
                    investors.append(name.strip())
            else:
                investors.append(np_investor[i].strip())
                

# stored investors in Dict.keys and 
# stored values maximum number of times invested In a different startup and 
#  their investment type is Private Equity for each investor in Dict.values                
Dict = {}
for key in investors:
    if key in Dict:
        Dict[key] += 1
    else:
        Dict[key] = 1

del Dict[""]

x = list(Dict.keys())
y = list(Dict.values())

np_x = np.array(x)
np_y = np.array(y)

# sort the np_x using np_y
np_x = np_x[np.argsort(np_y)]
np_y = np.sort(np_y)

np_x = np_x[len(np_x)-1: len(np_x) -1-5 : -1]
np_y = np_y[len(np_y)-1: len(np_y) -1-5 : -1]

# plot bar graph between investors and maximum number of times invested In a startup and 
# their investment type is Crowdfunding or Seed Funding for each investor 
plt.bar(np_x, np_y)
plt.grid()
plt.xticks(rotation = 40)
plt.show()

for i in range(len(np_x)):
    print(np_x[i], np_y[i])
# Out:
# Sequoia Capital 59
# Accel Partners 46
# Kalaari Capital 38
# SAIF Partners 35
# Blume Ventures 29
